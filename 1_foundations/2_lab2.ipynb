# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
#!pip install anthropic
from anthropic import Anthropic
from IPython.display import Markdown, display
# Out:
# Requirement already satisfied: anthropic in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (0.111.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from anthropic) (4.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)

# %%
# Always remember to do this!
load_dotenv(override=True)
print(os.getenv("GEMINI_API_KEY"))  # should print your key, not None
# Out:
# None

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GEMINI_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AQ
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-4o",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 openai = OpenAI()
# ----> 2 response = openai.chat.completions.create(
#       3     model="gpt-4o",
#       4     messages=messages,
#       5 )
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1251, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1204 def create(
#    1205     self,
#    (...)   1248     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1249 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1250     validate_response_format(response_format)
# -> 1251     return self._post(
#    1252         "/chat/completions",
#    1253         body=maybe_transform(
#    1254             {
#    1255                 "messages": messages,
#    1256                 "model": model,
#    1257                 "audio": audio,
#    1258                 "frequency_penalty": frequency_penalty,
#    1259                 "function_call": function_call,
#    1260                 "functions": functions,
#    1261                 "logit_bias": logit_bias,
#    1262                 "logprobs": logprobs,
#    1263                 "max_completion_tokens": max_completion_tokens,
#    1264                 "max_tokens": max_tokens,
#    1265                 "metadata": metadata,
#    1266                 "modalities": modalities,
#    1267                 "moderation": moderation,
#    1268                 "n": n,
#    1269                 "parallel_tool_calls": parallel_tool_calls,
#    1270                 "prediction": prediction,
#    1271                 "presence_penalty": presence_penalty,
#    1272                 "prompt_cache_key": prompt_cache_key,
#    1273                 "prompt_cache_retention": prompt_cache_retention,
#    1274                 "reasoning_effort": reasoning_effort,
#    1275                 "response_format": response_format,
#    1276                 "safety_identifier": safety_identifier,
#    1277                 "seed": seed,
#    1278                 "service_tier": service_tier,
#    1279                 "stop": stop,
#    1280                 "store": store,
#    1281                 "stream": stream,
#    1282                 "stream_options": stream_options,
#    1283                 "temperature": temperature,
#    1284                 "tool_choice": tool_choice,
#    1285                 "tools": tools,
#    1286                 "top_logprobs": top_logprobs,
#    1287                 "top_p": top_p,
#    1288                 "user": user,
#    1289                 "verbosity": verbosity,
#    1290                 "web_search_options": web_search_options,
#    1291             },
#    1292             completion_create_params.CompletionCreateParamsStreaming
#    1293             if stream
#    1294             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1295         ),
#    1296         options=make_request_options(
#    1297             extra_headers=extra_headers,
#    1298             extra_query=extra_query,
#    1299             extra_body=extra_body,
#    1300             timeout=timeout,
#    1301             security={"bearer_auth": True},
#    1302         ),
#    1303         cast_to=ChatCompletion,
#    1304         stream=stream or False,
#    1305         stream_cls=Stream[ChatCompletionChunk],
#    1306     )
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
# !pip install groq
from groq import Groq
import os

client = Groq(api_key=os.getenv("GROQ_API_KEY"))  # free key from console.groq.com

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=messages,  # works exactly like OpenAI
)
question = response.choices[0].message.content
print(question)
# Out:
# Collecting groq
#   Downloading groq-1.5.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from groq) (4.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from groq) (2.13.4)
# Requirement already satisfied: sniffio in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from anyio<5,>=3.5.0->groq) (3.18)
# Requirement already satisfied: certifi in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from httpx<1,>=0.23.0->groq) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->groq) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-1.5.0-py3-none-any.whl (143 kB)
# Installing collected packages: groq
# Successfully installed groq-1.5.0
# A hypothetical society has developed a predictive algorithm capable of determining with 95% accuracy the likelihood that an individual will commit a serious crime within the next five years. The algorithm considers numerous variables, including genetic predispositions, socioeconomic factors, environmental influences, and past behavior.
#
# Does it morally justify the use of this algorithm to deny certain individuals access to educational and employment opportunities, potentially altering their life trajectory, in order to prevent a statistically significant number of crimes from being committed, assuming no alternative method is available to achieve the same level of predictive accuracy?

# %%
#!pip install google-generativeai
genai.configure(api_key=google_api_key)
model = genai.GenerativeModel("gemini-2.0-flash")  # updated model name
response = model.generate_content(messages[-1]["content"])
question = response.text
print(question)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[35], line 4
#       1 #!pip install google-generativeai
#       2 genai.configure(api_key=google_api_key)
#       3 model = genai.GenerativeModel("gemini-2.0-flash")  # updated model name
# ----> 4 response = model.generate_content(messages[-1]["content"])
#       5 question = response.text
#       6 print(question)
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     208 if not predicate_fn(exc):
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#     216     on_error_fn(exc)
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\google\api_core\grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash
# Please retry in 24.72230581s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , retry_delay {
#   seconds: 24
# }
# ]

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[38], line 7
#       3 # Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins
#       4
#       5 model_name = "gpt-5-nano"
#       6
# ----> 7 response = openai.chat.completions.create(model=model_name, messages=messages)
#       8 answer = response.choices[0].message.content
#       9
#      10 display(Markdown(answer))
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1251, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1204 def create(
#    1205     self,
#    (...)   1248     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1249 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1250     validate_response_format(response_format)
# -> 1251     return self._post(
#    1252         "/chat/completions",
#    1253         body=maybe_transform(
#    1254             {
#    1255                 "messages": messages,
#    1256                 "model": model,
#    1257                 "audio": audio,
#    1258                 "frequency_penalty": frequency_penalty,
#    1259                 "function_call": function_call,
#    1260                 "functions": functions,
#    1261                 "logit_bias": logit_bias,
#    1262                 "logprobs": logprobs,
#    1263                 "max_completion_tokens": max_completion_tokens,
#    1264                 "max_tokens": max_tokens,
#    1265                 "metadata": metadata,
#    1266                 "modalities": modalities,
#    1267                 "moderation": moderation,
#    1268                 "n": n,
#    1269                 "parallel_tool_calls": parallel_tool_calls,
#    1270                 "prediction": prediction,
#    1271                 "presence_penalty": presence_penalty,
#    1272                 "prompt_cache_key": prompt_cache_key,
#    1273                 "prompt_cache_retention": prompt_cache_retention,
#    1274                 "reasoning_effort": reasoning_effort,
#    1275                 "response_format": response_format,
#    1276                 "safety_identifier": safety_identifier,
#    1277                 "seed": seed,
#    1278                 "service_tier": service_tier,
#    1279                 "stop": stop,
#    1280                 "store": store,
#    1281                 "stream": stream,
#    1282                 "stream_options": stream_options,
#    1283                 "temperature": temperature,
#    1284                 "tool_choice": tool_choice,
#    1285                 "tools": tools,
#    1286                 "top_logprobs": top_logprobs,
#    1287                 "top_p": top_p,
#    1288                 "user": user,
#    1289                 "verbosity": verbosity,
#    1290                 "web_search_options": web_search_options,
#    1291             },
#    1292             completion_create_params.CompletionCreateParamsStreaming
#    1293             if stream
#    1294             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1295         ),
#    1296         options=make_request_options(
#    1297             extra_headers=extra_headers,
#    1298             extra_query=extra_query,
#    1299             extra_body=extra_body,
#    1300             timeout=timeout,
#    1301             security={"bearer_auth": True},
#    1302         ),
#    1303         cast_to=ChatCompletion,
#    1304         stream=stream or False,
#    1305         stream_cls=Stream[ChatCompletionChunk],
#    1306     )
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
from groq import Groq

groq_client = Groq(api_key=os.getenv("GROQ_API_KEY"))

model_name = "llama-3.1-8b-instant"  # fast & free
# Other options:
# "llama-3.3-70b-versatile"   # more capable, still free
# "mixtral-8x7b-32768"        # good for reasoning

response = groq_client.chat.completions.create(
    model=model_name,
    messages=messages
)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# The use of this algorithm raises complex moral and ethical concerns. While it could potentially prevent a significant number of crimes, denying individuals access to educational and employment opportunities could have far-reaching consequences that compromise their autonomy, dignity, and humanity.
#
# Here are some arguments against using the algorithm in this way:
#
# 1. **Predictive accuracy does not equal destiny**: A 95% accuracy rate may seem impressive, but it also means 5% of individuals predicted to commit crimes may not actually do so. This margin of error raises concerns about false positives and the potential for wrongful targeting of individuals.
# 2. **Stereotyping and stigmatization**: By identifying individuals as "high-risk" based on a set of predictive factors, the algorithm may perpetuate discriminatory stereotypes and stigmatize certain groups, such as those from lower socioeconomic backgrounds or with mental health conditions.
# 3. **Targeting the vulnerable**: The algorithm may disproportionately target individuals who are already vulnerable, such as those who are young, marginalized, or struggling financially. This could exacerbate existing social inequalities and create a self-fulfilling prophecy.
# 4. **Lack of control and agency**: By denying individuals access to educational and employment opportunities, the algorithm would be effectively controlling their life trajectory without their consent or input. This raises concerns about autonomy and the right to make choices about one's own life.
# 5. **Alternative methods**: The algorithm's high predictive accuracy may be due in part to its reliance on socioeconomic factors, which can be influenced by systemic inequalities. Instead of relying on the algorithm, policymakers might focus on addressing the root causes of crime, such as poverty, lack of education and job opportunities, and mental health issues.
# 6. **Potential for misuse**: The algorithm could be used to justify discriminatory practices, such as targeting specific racial or ethnic groups, or to justify the expansion of the prison system.
#
# To justify the use of the algorithm, one might argue that:
#
# 1. **Preventing harm**: By preventing a statistically significant number of crimes, the algorithm could save lives and reduce the burden on law enforcement and the justice system.
# 2. **Evidence-based decision-making**: The algorithm's high predictive accuracy provides a data-driven approach to decision-making, which could lead to more effective crime prevention strategies.
#
# However, even in the presence of strong evidence, the moral justification for using the algorithm to deny individuals access to educational and employment opportunities is dubious. This approach raises more questions than answers:
#
# 1. **What are the long-term consequences of "preventing" crime by targeting individuals?**
# 2. **How will you ensure that the algorithm is transparent, fair, and unbiased?**
# 3. **What safeguards will you put in place to prevent over-reliance on the algorithm and potential misuse?**
#
# Ultimately, the use of this algorithm should be approached with caution and rigorous ethical consideration. While it may have potential benefits, its risks and limitations must be thoroughly explored and addressed before it is used to inform high-stakes decisions about individual lives.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[40], line 6
#       2
#       3 model_name = "claude-sonnet-4-5"
#       4
#       5 claude = Anthropic()
# ----> 6 response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
#       7 answer = response.content[0].text
#       8
#       9 display(Markdown(answer))
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\anthropic\resources\messages\messages.py:1018, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#    1011 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#    1012     warnings.warn(
#    1013         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1014         UserWarning,
#    1015         stacklevel=3,
#    1016     )
# -> 1018 return self._post(
#    1019     "/v1/messages",
#    1020     body=maybe_transform(
#    1021         {
#    1022             "max_tokens": max_tokens,
#    1023             "messages": messages,
#    1024             "model": model,
#    1025             "cache_control": cache_control,
#    1026             "container": container,
#    1027             "inference_geo": inference_geo,
#    1028             "metadata": metadata,
#    1029             "output_config": output_config,
#    1030             "service_tier": service_tier,
#    1031             "stop_sequences": stop_sequences,
#    1032             "stream": stream,
#    1033             "system": system,
#    1034             "temperature": temperature,
#    1035             "thinking": thinking,
#    1036             "tool_choice": tool_choice,
#    1037             "tools": tools,
#    1038             "top_k": top_k,
#    1039             "top_p": top_p,
#    1040         },
#    1041         message_create_params.MessageCreateParamsStreaming
#    1042         if stream
#    1043         else message_create_params.MessageCreateParamsNonStreaming,
#    1044     ),
#    1045     options=make_request_options(
#    1046         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1047     ),
#    1048     cast_to=Message,
#    1049     stream=stream or False,
#    1050     stream_cls=Stream[RawMessageStreamEvent],
#    1051 )
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\anthropic\_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\anthropic\_base_client.py:1195, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192     if not response.is_closed:
#    1193         response.read()
# -> 1195     raise self._make_status_error_from_response(response) from None
#    1197 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011CcJf65Xh9xAMdFjDZM1ri'}

# %%
from groq import Groq

model_name = "llama-3.3-70b-versatile"  # most capable free model on Groq

groq_client = Groq(api_key=os.getenv("GROQ_API_KEY"))
response = groq_client.chat.completions.create(
    model=model_name,
    messages=messages
)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# The use of a predictive algorithm to deny individuals access to educational and employment opportunities raises significant moral concerns. While the goal of preventing crimes is laudable, it is not morally justifiable to use this algorithm in the proposed manner for several reasons:
#
# 1. **Presumption of Innocence**: The algorithm's prediction is based on probability, not certainty. This means that 5% of individuals identified as high-risk will not commit a crime, and they will be unfairly denied opportunities. It is essential to presume innocence until proven guilty, rather than punishing individuals for potential future actions.
# 2. **Discrimination and Bias**: The algorithm may perpetuate existing social biases and discrimination, particularly if the variables used to train the model reflect historical inequalities. For example, socioeconomic factors may disproportionately affect marginalized communities, leading to unfair targeting of these groups.
# 3. **Lack of Personal Autonomy**: Denying individuals access to opportunities based on a statistical prediction undermines their autonomy and freedom to make choices about their lives. People have the right to pursue education and employment, even if they may be at a higher risk of committing a crime.
# 4. **Unintended Consequences**: Implementing such a system could lead to unintended consequences, such as:
# 	* Labeling individuals as "high-risk" can become a self-fulfilling prophecy, as they may become more likely to engage in criminal behavior due to the stigma and limited opportunities.
# 	* The lack of access to education and employment may exacerbate socioeconomic issues, potentially increasing the likelihood of crime.
# 	* The system may create a culture of suspicion, where individuals are viewed as potential threats rather than as members of society deserving of support and rehabilitation.
# 5. **Alternative Approaches**: Instead of relying solely on predictive algorithms, it is essential to explore alternative methods that focus on rehabilitation, social support, and addressing the root causes of crime. This could include:
# 	* Providing access to education, job training, and mental health services to individuals at risk.
# 	* Implementing community-based programs that promote social cohesion and address socioeconomic disparities.
# 	* Fostering a culture of rehabilitation and restorative justice, rather than punishment and exclusion.
# 6. **Transparency and Accountability**: The development and implementation of such an algorithm should be transparent, with clear guidelines and oversight mechanisms in place to ensure accountability and prevent abuse.
# 7. **Human Rights**: The use of predictive algorithms to deny opportunities raises concerns about human rights, including the right to education, employment, and non-discrimination. It is essential to ensure that any system implemented respects and protects these fundamental rights.
#
# In conclusion, while the predictive algorithm may be effective in identifying individuals at risk of committing crimes, it is not morally justifiable to use it to deny access to educational and employment opportunities. Instead, a more nuanced approach should be adopted, focusing on rehabilitation, social support, and addressing the root causes of crime, while ensuring that individual rights and autonomy are respected.

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# This hypothetical scenario presents a profound ethical dilemma, pitting the collective good of crime prevention against individual rights and liberties. While the algorithm's 95% accuracy rate is very high, most ethical frameworks would find its use to deny fundamental opportunities morally problematic.
#
# Let's break down the ethical considerations:
#
# **Arguments for Justification (primarily Utilitarian/Consequentialist):**
#
# 1.  **Prevention of Harm:** The primary argument is that preventing a "statistically significant number of serious crimes" would save lives, prevent suffering, and reduce societal costs associated with crime. From a purely utilitarian perspective, if the net benefit (reduced crime) outweighs the harm (denial of opportunities), it could be argued as justified.
# 2.  **High Accuracy:** The 95% accuracy rate is a powerful factor. It suggests that a large majority of those identified would indeed commit serious crimes.
# 3.  **No Alternative:** The premise states no alternative method exists to achieve the same level of predictive accuracy, suggesting this is the most effective means to the desired end of crime prevention.
#
# **Arguments Against Justification (primarily Deontological/Rights-Based and Virtue Ethics):**
#
# 1.  **Violation of Individual Rights and Autonomy:**
#     *   **Presumption of Innocence:** A cornerstone of modern justice systems is that individuals are presumed innocent until proven guilty. This algorithm effectively presumes a high likelihood of guilt for a future crime, punishing individuals before any actual wrongdoing.
#     *   **Right to Opportunity:** Denying access to education and employment fundamentally curtails an individual's right to pursue a fulfilling life, improve their socioeconomic status, and contribute to society.
#     *   **Free Will and Self-Determination:** Individuals are denied the chance to make their own choices, to change their path, or to prove the algorithm wrong. It treats individuals as deterministic outcomes of variables rather than agents with free will.
#
# 2.  **False Positives (5% Inaccuracy):**
#     *   While 5% may seem small, it means that 1 in 20 individuals identified by the algorithm would *not* have committed a serious crime. These individuals would suffer profound, lifelong consequences – denied education, employment, and social mobility – for actions they would never have taken. This is a severe injustice for a significant number of people.
#     *   The harm inflicted on these innocent individuals is immense and cannot be easily dismissed for the "greater good."
#
# 3.  **Self-Fulfilling Prophecy:**
#     *   Denying education and employment opportunities could, paradoxically, increase the likelihood of crime. If legitimate pathways to success and survival are blocked, individuals might be driven to illegal means out of desperation, resentment, or a lack of alternatives. This could make the algorithm's predictions "come true" not because of inherent predisposition, but because of the societal reaction to the prediction.
#
# 4.  **Moral Responsibility and Blame:**
#     *   If society denies individuals the means to live a legitimate life based on a prediction, what is society's responsibility for any subsequent criminal behavior? Does it absolve the individual of moral responsibility, or does it shift some of the blame to the system that limited their choices?
#
# 5.  **Discrimination and Systemic Bias:**
#     *   Even if the algorithm is designed to be "objective," if it incorporates socioeconomic factors or genetic predispositions, it risks perpetuating existing societal inequalities or creating new forms of discrimination. It could disproportionately impact certain communities or groups already facing systemic disadvantages, trapping them in a cycle of limited opportunity.
#
# 6.  **Slippery Slope:**
#     *   If this is deemed morally justifiable for "serious crimes," where does the line get drawn? Could it be extended to less serious offenses? Could it be used to deny other rights or opportunities, leading to a dystopian "pre-crime" society where individuals are constantly monitored and judged based on potential rather than actual actions?
#
# **Conclusion:**
#
# From a moral standpoint, the use of this algorithm to deny educational and employment opportunities is **not morally justified**.
#
# While the goal of preventing serious crime is laudable, the method employed fundamentally violates principles of individual liberty, the presumption of innocence, due process, and the right to opportunity. The harm inflicted on the 5% of false positives is an unacceptable injustice, and the potential for creating a self-fulfilling prophecy, exacerbating existing inequalities, and setting a dangerous precedent outweighs the utilitarian benefits of crime reduction.
#
# A just society should focus on rehabilitative, supportive, and interventionist strategies to address the root causes of crime, rather than preemptively punishing individuals for actions they might commit. The ethical cost of such a system is too high.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[43], line 4
#       1 deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
#       2 model_name = "deepseek-chat"
#       3
# ----> 4 response = deepseek.chat.completions.create(model=model_name, messages=messages)
#       5 answer = response.choices[0].message.content
#       6
#       7 display(Markdown(answer))
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1251, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1204 def create(
#    1205     self,
#    (...)   1248     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1249 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1250     validate_response_format(response_format)
# -> 1251     return self._post(
#    1252         "/chat/completions",
#    1253         body=maybe_transform(
#    1254             {
#    1255                 "messages": messages,
#    1256                 "model": model,
#    1257                 "audio": audio,
#    1258                 "frequency_penalty": frequency_penalty,
#    1259                 "function_call": function_call,
#    1260                 "functions": functions,
#    1261                 "logit_bias": logit_bias,
#    1262                 "logprobs": logprobs,
#    1263                 "max_completion_tokens": max_completion_tokens,
#    1264                 "max_tokens": max_tokens,
#    1265                 "metadata": metadata,
#    1266                 "modalities": modalities,
#    1267                 "moderation": moderation,
#    1268                 "n": n,
#    1269                 "parallel_tool_calls": parallel_tool_calls,
#    1270                 "prediction": prediction,
#    1271                 "presence_penalty": presence_penalty,
#    1272                 "prompt_cache_key": prompt_cache_key,
#    1273                 "prompt_cache_retention": prompt_cache_retention,
#    1274                 "reasoning_effort": reasoning_effort,
#    1275                 "response_format": response_format,
#    1276                 "safety_identifier": safety_identifier,
#    1277                 "seed": seed,
#    1278                 "service_tier": service_tier,
#    1279                 "stop": stop,
#    1280                 "store": store,
#    1281                 "stream": stream,
#    1282                 "stream_options": stream_options,
#    1283                 "temperature": temperature,
#    1284                 "tool_choice": tool_choice,
#    1285                 "tools": tools,
#    1286                 "top_logprobs": top_logprobs,
#    1287                 "top_p": top_p,
#    1288                 "user": user,
#    1289                 "verbosity": verbosity,
#    1290                 "web_search_options": web_search_options,
#    1291             },
#    1292             completion_create_params.CompletionCreateParamsStreaming
#    1293             if stream
#    1294             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1295         ),
#    1296         options=make_request_options(
#    1297             extra_headers=extra_headers,
#    1298             extra_query=extra_query,
#    1299             extra_body=extra_body,
#    1300             timeout=timeout,
#    1301             security={"bearer_auth": True},
#    1302         ),
#    1303         cast_to=ChatCompletion,
#    1304         stream=stream or False,
#    1305         stream_cls=Stream[ChatCompletionChunk],
#    1306     )
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# APIStatusError: Error code: 402 - {'error': {'message': 'Insufficient Balance', 'type': 'unknown_error', 'param': None, 'code': 'invalid_request_error'}}

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **Short answer:**
# Most mainstream moral frameworks would *not* consider it ethically permissible to deny people education or employment on the basis of a statistical prediction, even if that prediction could avert a large number of serious crimes and no equally accurate alternative exists. The harms of false‑positive judgments, the violation of fundamental rights, the risk of systemic bias, and the corrosive social consequences of “pre‑emptive” discrimination generally outweigh the utilitarian gain of preventing some future offenses.
#
# Below is a detailed analysis that explains why, drawing on several major ethical traditions, legal principles, and practical considerations.
#
# ---
#
# ## 1. The Core Moral Conflict
#
# | **Goal** | **Means** | **Key Moral Tension** |
# |----------|-----------|-----------------------|
# | Prevent serious crimes (utilitarian benefit) | Deny education/employment to those predicted to be high‑risk (pre‑emptive punishment) | Is it just to punish—or at least disadvantage—a person for something they have not yet done? |
#
# The dilemma pits **consequentialist reasoning** (maximizing overall safety) against **deontological and rights‑based reasoning** (respecting each individual’s autonomy, dignity, and equal treatment).
#
# ---
#
# ## 2. Consequentialist (Utilitarian / Consequence‑Based) Perspective
#
# ### 2.1. Expected‑Utility Calculation
#
# - **Accuracy:** 95 % true‑positive rate, 5 % false‑positive rate.
# - **Population size:** Suppose 1 million people are screened.
#   - True positives ≈ 0.95 × N<sub>high‑risk</sub>
#   - False positives ≈ 0.05 × N<sub>low‑risk</sub>
# - **Cost of denial:** Loss of education/employment reduces lifetime earnings, mental health, and social participation for each denied person.
# - **Benefit of prevented crimes:** Each serious crime avoided spares victims, families, and the criminal‑justice system large tangible and intangible costs.
#
# A rough utilitarian model would compare:
#
# ```
# Total Benefit = (Number of crimes prevented) × (average societal cost per crime)
# Total Harm    = (Number of false positives) × (average loss per person denied opportunity)
# ```
#
# If the **harm to false‑positives** exceeds the **benefit of crimes prevented**, a utilitarian calculus would deem the policy unjustifiable. Empirical studies on predictive policing show that even high‑accuracy tools produce sizable false‑positive pools because the base rate of serious crime is low. For a rare event, a 95 % “accuracy” can still misclassify many people.
#
# ### 2.2. Long‑Term Systemic Effects
#
# - **Stigmatization & Social Exclusion:** Systematically barring a segment of the population from key life pathways creates a self‑fulfilling prophecy: marginalized individuals face higher stress, reduced social capital, and limited legitimate avenues for success, all of which *increase* the probability of future offending.
# - **Erosion of Trust:** When institutions are seen as arbitrarily denying opportunities, public trust in education, labor markets, and the state declines, reducing overall societal cooperation—a crucial component of collective safety.
# - **Feedback Loops:** The algorithm is trained on historical data that already reflect past discrimination. Deploying it reinforces those patterns, potentially *degrading* the very predictive accuracy over time.
#
# Consequentialist reasoning must therefore factor in these indirect harms, which can outweigh the immediate crime‑prevention benefit.
#
# ---
#
# ## 3. Deontological / Rights‑Based Perspective
#
# ### 3.1. The Principle of Individual Moral Agency
#
# - **Punishment for non‑act:** Classical deontological ethics (e.g., Kantian) holds that individuals must be treated as ends in themselves, not merely as means to societal safety. Denying someone a chance at education or work *because they might* commit a crime treats them as a means to an end (crime reduction), violating their intrinsic dignity.
# - **Presumption of Innocence:** The legal and moral norm “innocent until proven guilty” is a safeguard against precisely this sort of pre‑emptive sanction. Using a statistical forecast to impose real penalties collapses that safeguard.
#
# ### 3.2. Equality & Non‑Discrimination
#
# - Even if the algorithm is “technically neutral,” the variables it uses (genetics, socioeconomic status, environment) are closely tied to protected classes (race, class, disability). Denying opportunities based on those variables effectively **discriminates** on the basis of group membership, violating modern conceptions of equal treatment.
# - Many moral and legal theories (e.g., Rawls’s *justice as fairness*) require that social and economic inequalities be arranged so that they benefit the *least advantaged*. A policy that systematically harms the disadvantaged to protect the majority fails this test.
#
# ### 3.3. Autonomy & Fair Process
#
# - Moral agency requires **fair process** (procedural justice). If an algorithm decides a person’s future without transparent appeal, it denies them the procedural rights that are essential to a just society.
#
# ---
#
# ## 4. Virtue‑Ethical and Communitarian Concerns
#
# - **Character of Society:** A community that pre‑emptively excludes people based on risk scores cultivates suspicion, fear, and a punitive ethos, eroding virtues such as compassion, solidarity, and forgiveness.
# - **Rehabilitation vs. Exclusion:** Virtue ethics emphasizes nurturing the potential for moral growth. Denying education/employment removes the very conditions that enable individuals to develop better habits and values.
#
# ---
#
# ## 5. Legal and International Human‑Rights Context
#
# | Instrument | Relevant Provision | Implication for the Algorithm |
# |------------|-------------------|------------------------------|
# | **Universal Declaration of Human Rights (UDHR)** | Art. 23: “Everyone has the right to work….” | Systematic denial of work based on prediction violates this right. |
# | **International Covenant on Economic, Social and Cultural Rights (ICESCR)** | Art. 2(2): “The steps…shall be taken without discrimination.” | Predictive exclusion based on socioeconomic/genetic factors would be discriminatory. |
# | **EU General Data Protection Regulation (GDPR)** | Art. 22: “Automated decision‑making…significant effect…must be subject to human review.” | The algorithm would need meaningful human oversight, which is hard to reconcile with blanket bans. |
# | **US Constitution (14th Amendment)** | Due Process Clause | Pre‑emptive denial without individualized due process likely violates procedural due process. |
#
# These legal norms reinforce the moral conclusion that such a policy would be impermissible in most jurisdictions.
#
# ---
#
# ## 6. The “No Alternative” Assumption – A Critical Examination
#
# Even if we *temporarily* accept that no other method matches the algorithm’s predictive power, we must ask:
#
# 1. **Is the assumption empirically sound?**
#    - Predictive models often improve with additional data and with more transparent, community‑based interventions (e.g., early education, mental‑health services). Declaring a “no alternative” prematurely shuts down research into less invasive, more equitable solutions.
#
# 2. **Do we have a moral right to accept a “best‑available” method that is itself deeply unjust?**
#    - The *means* must meet a minimal ethical threshold. A method that violates fundamental rights cannot be justified merely because it is the most effective *available* tool.
#
# 3. **Is the trade‑off proportionate?**
#    - Proportionality demands that the severity of the intrusion (denial of life‑shaping opportunities) be proportional to the seriousness of the threat. In most realistic calculations, the intrusion is *far* more severe than the prevented harm, especially given the high stakes for false positives.
#
# ---
#
# ## 7. Practical Counter‑Arguments & Rebuttals
#
# | **Common pro‑algorithm argument** | **Rebuttal** |
# |-----------------------------------|--------------|
# | *“The algorithm saves lives; we must act.”* | Saving lives is a laudable aim, but a policy that sacrifices the rights and futures of many innocent people creates a different kind of societal harm that can be equally lethal (social decay, increased violence, loss of trust). |
# | *“If we could only target the high‑risk group, crime would plummet.”* | The high‑risk group is identified *statistically*, not individually. Many of those labeled high‑risk would never have committed a crime; the policy would create a self‑fulfilling high‑risk class. |
# | *“We can’t afford alternative programs.”* | Budget constraints are a policy issue, not a moral justification for rights violations. Moreover, investing in universal prevention (education, health, community development) often yields higher cost‑effectiveness than punitive exclusion. |
# | *“The algorithm is neutral; bias is a myth.”* | Neutrality is an illusion when inputs reflect historic inequities. Genetic, socioeconomic, and environmental variables are socially constructed proxies for race, class, and geography. |
# | *“We can include a human review step to mitigate errors.”* | Human reviewers inherit the same biased data and are often subject to “automation bias” (over‑reliance on the algorithm). Moreover, the *structural* impact—loss of opportunity—remains even after a review. |
#
# ---
#
# ## 8. A More Ethical Path Forward
#
# 1. **Use the algorithm *only* for *supportive* interventions**, not for punitive exclusion.
#    - Example: Flag high‑risk individuals for *additional* counseling, mentorship, or targeted social services that aim to reduce risk while preserving opportunity.
#
# 2. **Invest in upstream prevention**: universal early‑childhood education, mental‑health care, job‑training programs, and community policing models have demonstrated efficacy in reducing crime without violating rights.
#
# 3. **Ensure transparency, accountability, and continuous auditing** of any predictive system. Include independent ethicists, community representatives, and legal scholars in oversight.
#
# 4. **Implement robust due‑process safeguards**: any decision that materially affects a person’s life (e.g., hiring, admission) must be explainable, contestable, and based on individualized evidence—not a statistical score.
#
# 5. **Collect and analyze data on false‑positive harms** to monitor whether the system is causing more damage than benefit. If the harm outweighs the benefit, discontinue the practice.
#
# ---
#
# ## 9. Bottom‑Line Moral Verdict
#
# - **From a deontological and rights‑based standpoint:** Denying education or employment on the basis of a predictive algorithm is morally impermissible because it punishes people for crimes they have not committed, violates the principle of proportionality, and breaches the right to equal treatment and due process.
# - **From a consequentialist standpoint:** Even if the algorithm is highly accurate, the aggregate harms—false‑positive losses, social destabilization, reinforcement of structural inequality—are likely to outweigh the benefits of crimes prevented, especially when the baseline rate of serious crime is low.
# - **From a virtue‑ethics/communitarian standpoint:** Such a policy erodes the moral character of the community, replacing compassion and rehabilitation with suspicion and exclusion.
#
# **Therefore, the use of the algorithm to *deny* individuals access to education or employment is not morally justified, even under the “no alternative” assumption.** The ethically appropriate use of predictive tools is to *inform* supportive, restorative measures that enhance rather than restrict life opportunities.

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏  58 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 1.1 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 1.7 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 3.0 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 3.7 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 4.0 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 4.5 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 5.1 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 5.4 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 6.0 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 6.6 MB/2.0 GB  6.6 MB/s    5m7spulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 6.9 MB/2.0 GB  6.6 MB/s    5m6spulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 7.6 MB/2.0 GB  6.6 MB/s    5m6spulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 8.1 MB/2.0 GB  6.6 MB/s    5m6spulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 8.4 MB/2.0 GB  6.6 MB/s    5m6spulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 9.0 MB/2.0 GB  6.6 MB/s    5m6spulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 9.6 MB/2.0 GB  6.6 MB/s    5m6spulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 9.8 MB/2.0 GB  6.6 MB/s    5m6spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  10 MB/2.0 GB  6.6 MB/s    5m6spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  11 MB/2.0 GB  6.6 MB/s    5m6spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  11 MB/2.0 GB  6.6 MB/s    5m6spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  11 MB/2.0 GB  5.8 MB/s   5m45spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  12 MB/2.0 GB  5.8 MB/s   5m45spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  12 MB/2.0 GB  5.8 MB/s   5m45spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  13 MB/2.0 GB  5.8 MB/s   5m45spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  13 MB/2.0 GB  5.8 MB/s   5m45spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  14 MB/2.0 GB  5.8 MB/s   5m45spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  14 MB/2.0 GB  5.8 MB/s   5m44spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  15 MB/2.0 GB  5.8 MB/s   5m44spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  15 MB/2.0 GB  5.8 MB/s   5m44spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  16 MB/2.0 GB  5.8 MB/s   5m44spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  16 MB/2.0 GB  5.5 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  17 MB/2.0 GB  5.5 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  17 MB/2.0 GB  5.5 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  18 MB/2.0 GB  5.5 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  18 MB/2.0 GB  5.5 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  19 MB/2.0 GB  5.5 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  19 MB/2.0 GB  5.5 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  20 MB/2.0 GB  5.5 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  20 MB/2.0 GB  5.5 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  21 MB/2.0 GB  5.5 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  21 MB/2.0 GB  5.4 MB/s   6m13spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  22 MB/2.0 GB  5.4 MB/s   6m13spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  22 MB/2.0 GB  5.4 MB/s   6m13spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  22 MB/2.0 GB  5.4 MB/s   6m12spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  23 MB/2.0 GB  5.4 MB/s   6m12spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  23 MB/2.0 GB  5.4 MB/s   6m12spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  24 MB/2.0 GB  5.4 MB/s   6m12spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  24 MB/2.0 GB  5.4 MB/s   6m12spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  25 MB/2.0 GB  5.4 MB/s   6m12spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  25 MB/2.0 GB  5.4 MB/s   6m12spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  26 MB/2.0 GB  5.2 MB/s   6m21spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  26 MB/2.0 GB  5.2 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  27 MB/2.0 GB  5.2 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  27 MB/2.0 GB  5.2 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  28 MB/2.0 GB  5.2 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  28 MB/2.0 GB  5.2 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  29 MB/2.0 GB  5.2 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  29 MB/2.0 GB  5.2 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  29 MB/2.0 GB  5.2 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  30 MB/2.0 GB  5.2 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  31 MB/2.0 GB  5.2 MB/s   6m24spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  31 MB/2.0 GB  5.2 MB/s   6m24spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  32 MB/2.0 GB  5.2 MB/s   6m24spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  32 MB/2.0 GB  5.2 MB/s   6m24spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  32 MB/2.0 GB  5.2 MB/s   6m24spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  33 MB/2.0 GB  5.2 MB/s   6m24spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  33 MB/2.0 GB  5.2 MB/s   6m24spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  34 MB/2.0 GB  5.2 MB/s   6m24spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  34 MB/2.0 GB  5.2 MB/s   6m24spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  35 MB/2.0 GB  5.2 MB/s   6m23spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  35 MB/2.0 GB  5.2 MB/s   6m23spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  36 MB/2.0 GB  5.1 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  36 MB/2.0 GB  5.1 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  37 MB/2.0 GB  5.1 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  37 MB/2.0 GB  5.1 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  38 MB/2.0 GB  5.1 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  38 MB/2.0 GB  5.1 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  38 MB/2.0 GB  5.1 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  39 MB/2.0 GB  5.1 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  39 MB/2.0 GB  5.1 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  40 MB/2.0 GB  5.1 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  40 MB/2.0 GB  5.1 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  41 MB/2.0 GB  5.1 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  41 MB/2.0 GB  5.1 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  42 MB/2.0 GB  5.1 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  42 MB/2.0 GB  5.1 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  43 MB/2.0 GB  5.1 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  43 MB/2.0 GB  5.1 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  44 MB/2.0 GB  5.1 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  44 MB/2.0 GB  5.1 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  45 MB/2.0 GB  5.1 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  45 MB/2.0 GB  5.1 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  46 MB/2.0 GB  5.1 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  46 MB/2.0 GB  5.1 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  47 MB/2.0 GB  5.1 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  47 MB/2.0 GB  5.1 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  47 MB/2.0 GB  5.1 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  48 MB/2.0 GB  5.1 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  48 MB/2.0 GB  5.1 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  49 MB/2.0 GB  5.1 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  49 MB/2.0 GB  5.1 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  50 MB/2.0 GB  4.9 MB/s   6m44spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  50 MB/2.0 GB  4.9 MB/s   6m44spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  51 MB/2.0 GB  4.9 MB/s   6m44spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  51 MB/2.0 GB  4.9 MB/s   6m44spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  52 MB/2.0 GB  4.9 MB/s   6m43spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  52 MB/2.0 GB  4.9 MB/s   6m43spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  53 MB/2.0 GB  4.9 MB/s   6m43spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  53 MB/2.0 GB  4.9 MB/s   6m43spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  54 MB/2.0 GB  4.9 MB/s   6m43spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  54 MB/2.0 GB  4.9 MB/s   6m43spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  55 MB/2.0 GB  4.9 MB/s   6m44spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  55 MB/2.0 GB  4.9 MB/s   6m44spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  56 MB/2.0 GB  4.9 MB/s   6m44spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  56 MB/2.0 GB  4.9 MB/s   6m43spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  57 MB/2.0 GB  4.9 MB/s   6m43spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  57 MB/2.0 GB  4.9 MB/s   6m43spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  58 MB/2.0 GB  4.9 MB/s   6m43spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  58 MB/2.0 GB  4.9 MB/s   6m43spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  59 MB/2.0 GB  4.9 MB/s   6m43spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  59 MB/2.0 GB  4.9 MB/s   6m43spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  60 MB/2.0 GB  4.9 MB/s   6m43spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  60 MB/2.0 GB  4.9 MB/s   6m40spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  61 MB/2.0 GB  4.9 MB/s   6m40spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  61 MB/2.0 GB  4.9 MB/s   6m40spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  62 MB/2.0 GB  4.9 MB/s   6m40spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  62 MB/2.0 GB  4.9 MB/s   6m40spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  63 MB/2.0 GB  4.9 MB/s   6m40spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  63 MB/2.0 GB  4.9 MB/s   6m40spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  64 MB/2.0 GB  4.9 MB/s   6m40spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  64 MB/2.0 GB  4.9 MB/s   6m40spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  65 MB/2.0 GB  4.9 MB/s   6m39spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  65 MB/2.0 GB  4.9 MB/s   6m40spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  66 MB/2.0 GB  4.9 MB/s   6m40spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  66 MB/2.0 GB  4.9 MB/s   6m39spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  67 MB/2.0 GB  4.9 MB/s   6m39spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  67 MB/2.0 GB  4.9 MB/s   6m39spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  68 MB/2.0 GB  4.9 MB/s   6m39spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  68 MB/2.0 GB  4.9 MB/s   6m39spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  69 MB/2.0 GB  4.9 MB/s   6m39spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  69 MB/2.0 GB  4.9 MB/s   6m39spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  70 MB/2.0 GB  4.9 MB/s   6m39spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  70 MB/2.0 GB  4.9 MB/s   6m38spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  70 MB/2.0 GB  4.9 MB/s   6m38spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  71 MB/2.0 GB  4.9 MB/s   6m37spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  71 MB/2.0 GB  4.9 MB/s   6m37spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  72 MB/2.0 GB  4.9 MB/s   6m37spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  72 MB/2.0 GB  4.9 MB/s   6m37spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  73 MB/2.0 GB  4.9 MB/s   6m37spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  73 MB/2.0 GB  4.9 MB/s   6m37spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  74 MB/2.0 GB  4.9 MB/s   6m37spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  74 MB/2.0 GB  4.9 MB/s   6m37spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  75 MB/2.0 GB  4.9 MB/s   6m37spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  75 MB/2.0 GB  4.9 MB/s   6m37spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  75 MB/2.0 GB  4.9 MB/s   6m37spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  76 MB/2.0 GB  4.9 MB/s   6m36spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  77 MB/2.0 GB  4.9 MB/s   6m36spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  77 MB/2.0 GB  4.9 MB/s   6m36spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  77 MB/2.0 GB  4.9 MB/s   6m36spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  78 MB/2.0 GB  4.9 MB/s   6m36spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  78 MB/2.0 GB  4.9 MB/s   6m36spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  79 MB/2.0 GB  4.9 MB/s   6m36spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  79 MB/2.0 GB  4.9 MB/s   6m36spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  80 MB/2.0 GB  4.9 MB/s   6m36spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  80 MB/2.0 GB  4.9 MB/s   6m36spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  81 MB/2.0 GB  4.9 MB/s   6m36spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  81 MB/2.0 GB  4.9 MB/s   6m36spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  82 MB/2.0 GB  4.9 MB/s   6m36spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  82 MB/2.0 GB  4.9 MB/s   6m36spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  83 MB/2.0 GB  4.9 MB/s   6m36spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  83 MB/2.0 GB  4.9 MB/s   6m35spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  84 MB/2.0 GB  4.9 MB/s   6m35spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  84 MB/2.0 GB  4.9 MB/s   6m35spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  85 MB/2.0 GB  4.9 MB/s   6m33spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  85 MB/2.0 GB  4.9 MB/s   6m33spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  86 MB/2.0 GB  4.9 MB/s   6m33spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  86 MB/2.0 GB  4.9 MB/s   6m33spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  87 MB/2.0 GB  4.9 MB/s   6m33spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  87 MB/2.0 GB  4.9 MB/s   6m33spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  88 MB/2.0 GB  4.9 MB/s   6m33spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  88 MB/2.0 GB  4.9 MB/s   6m32spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  89 MB/2.0 GB  4.9 MB/s   6m32spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  89 MB/2.0 GB  4.9 MB/s   6m32spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  90 MB/2.0 GB  4.9 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  90 MB/2.0 GB  4.9 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  91 MB/2.0 GB  4.9 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  91 MB/2.0 GB  4.9 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  92 MB/2.0 GB  4.9 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  92 MB/2.0 GB  4.9 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  93 MB/2.0 GB  4.9 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  93 MB/2.0 GB  4.9 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  94 MB/2.0 GB  4.9 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  94 MB/2.0 GB  4.9 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  94 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  95 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  96 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  96 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  96 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  97 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  97 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  98 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  99 MB/2.0 GB  4.9 MB/s   6m27spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  99 MB/2.0 GB  4.9 MB/s   6m27spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  99 MB/2.0 GB  4.9 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 100 MB/2.0 GB  4.9 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 100 MB/2.0 GB  4.9 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 101 MB/2.0 GB  4.9 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 101 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 101 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 102 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 103 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 103 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 103 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 104 MB/2.0 GB  4.9 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 104 MB/2.0 GB  4.9 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 105 MB/2.0 GB  4.9 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 106 MB/2.0 GB  4.9 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 106 MB/2.0 GB  4.9 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 106 MB/2.0 GB  4.9 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 107 MB/2.0 GB  4.9 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 107 MB/2.0 GB  4.9 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 108 MB/2.0 GB  4.9 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 108 MB/2.0 GB  4.9 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 109 MB/2.0 GB  4.9 MB/s   6m30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 109 MB/2.0 GB  4.9 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 110 MB/2.0 GB  4.9 MB/s   6m29spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 110 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   6% ▕                  ▏ 111 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   6% ▕                  ▏ 111 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 112 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 112 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 113 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 113 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 114 MB/2.0 GB  4.9 MB/s   6m28spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 114 MB/2.0 GB  4.9 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 115 MB/2.0 GB  4.9 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 115 MB/2.0 GB  4.9 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 116 MB/2.0 GB  4.9 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 116 MB/2.0 GB  4.9 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 117 MB/2.0 GB  4.9 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 117 MB/2.0 GB  4.9 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 118 MB/2.0 GB  4.9 MB/s   6m26spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 118 MB/2.0 GB  4.9 MB/s   6m25spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 119 MB/2.0 GB  4.9 MB/s   6m25spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 119 MB/2.0 GB  5.0 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 120 MB/2.0 GB  5.0 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 120 MB/2.0 GB  5.0 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 121 MB/2.0 GB  5.0 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 121 MB/2.0 GB  5.0 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 122 MB/2.0 GB  5.0 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 122 MB/2.0 GB  5.0 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 123 MB/2.0 GB  5.0 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 123 MB/2.0 GB  5.0 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 124 MB/2.0 GB  5.0 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 124 MB/2.0 GB  5.0 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 125 MB/2.0 GB  5.0 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 125 MB/2.0 GB  5.0 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 126 MB/2.0 GB  5.0 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 126 MB/2.0 GB  5.0 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 126 MB/2.0 GB  5.0 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 127 MB/2.0 GB  5.0 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 128 MB/2.0 GB  5.0 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 128 MB/2.0 GB  5.0 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 128 MB/2.0 GB  5.0 MB/s   6m19spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 129 MB/2.0 GB  5.0 MB/s   6m21spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 129 MB/2.0 GB  5.0 MB/s   6m21spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 130 MB/2.0 GB  5.0 MB/s   6m21spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 130 MB/2.0 GB  5.0 MB/s   6m21spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 131 MB/2.0 GB  5.0 MB/s   6m21spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 131 MB/2.0 GB  5.0 MB/s   6m21spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 132 MB/2.0 GB  5.0 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 132 MB/2.0 GB  5.0 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 133 MB/2.0 GB  5.0 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 133 MB/2.0 GB  5.0 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 134 MB/2.0 GB  5.0 MB/s   6m20spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 134 MB/2.0 GB  4.9 MB/s   6m23spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 135 MB/2.0 GB  4.9 MB/s   6m23spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 135 MB/2.0 GB  4.9 MB/s   6m23spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 135 MB/2.0 GB  4.9 MB/s   6m23spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 136 MB/2.0 GB  4.9 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 136 MB/2.0 GB  4.9 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 137 MB/2.0 GB  4.9 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 138 MB/2.0 GB  4.9 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 138 MB/2.0 GB  4.9 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 138 MB/2.0 GB  4.9 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 139 MB/2.0 GB  4.9 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 139 MB/2.0 GB  4.9 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 140 MB/2.0 GB  4.9 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 140 MB/2.0 GB  4.9 MB/s   6m22spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 141 MB/2.0 GB  4.9 MB/s   6m21spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 141 MB/2.0 GB  4.9 MB/s   6m21spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 142 MB/2.0 GB  4.9 MB/s   6m21spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 142 MB/2.0 GB  4.9 MB/s   6m21spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 143 MB/2.0 GB  4.9 MB/s   6m21spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 144 MB/2.0 GB  4.9 MB/s   6m21spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 144 MB/2.0 GB  4.9 MB/s   6m19spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 144 MB/2.0 GB  4.9 MB/s   6m19spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 145 MB/2.0 GB  4.9 MB/s   6m19spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 145 MB/2.0 GB  4.9 MB/s   6m19spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 146 MB/2.0 GB  4.9 MB/s   6m19spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 146 MB/2.0 GB  4.9 MB/s   6m19spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 147 MB/2.0 GB  4.9 MB/s   6m19spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 147 MB/2.0 GB  4.9 MB/s   6m19spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 148 MB/2.0 GB  4.9 MB/s   6m18spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 148 MB/2.0 GB  4.9 MB/s   6m18spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 149 MB/2.0 GB  5.0 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 149 MB/2.0 GB  5.0 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 150 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 150 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 151 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 151 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 152 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 152 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 153 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 153 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 154 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 154 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 155 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 155 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 156 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 156 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 157 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 157 MB/2.0 GB  5.0 MB/s   6m14spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 158 MB/2.0 GB  5.0 MB/s   6m13spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 158 MB/2.0 GB  5.0 MB/s   6m13spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 158 MB/2.0 GB  5.0 MB/s   6m13spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 159 MB/2.0 GB  4.9 MB/s   6m16spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 160 MB/2.0 GB  4.9 MB/s   6m16spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 160 MB/2.0 GB  4.9 MB/s   6m16spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 160 MB/2.0 GB  4.9 MB/s   6m16spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 161 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 161 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 162 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 162 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 163 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 163 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 164 MB/2.0 GB  4.9 MB/s   6m17spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 164 MB/2.0 GB  4.9 MB/s   6m17spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 165 MB/2.0 GB  4.9 MB/s   6m16spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 165 MB/2.0 GB  4.9 MB/s   6m16spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 166 MB/2.0 GB  4.9 MB/s   6m16spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 166 MB/2.0 GB  4.9 MB/s   6m16spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 167 MB/2.0 GB  4.9 MB/s   6m16spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 167 MB/2.0 GB  4.9 MB/s   6m16spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 168 MB/2.0 GB  4.9 MB/s   6m16spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 168 MB/2.0 GB  4.9 MB/s   6m16spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 169 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 169 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 170 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 170 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 171 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 171 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 172 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 172 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 173 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 173 MB/2.0 GB  4.9 MB/s   6m15spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 174 MB/2.0 GB  4.9 MB/s   6m13spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 174 MB/2.0 GB  4.9 MB/s   6m13spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 174 MB/2.0 GB  4.9 MB/s   6m13spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 175 MB/2.0 GB  4.9 MB/s   6m12spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 176 MB/2.0 GB  4.9 MB/s   6m12spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 176 MB/2.0 GB  4.9 MB/s   6m12spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 176 MB/2.0 GB  4.9 MB/s   6m12spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 177 MB/2.0 GB  4.9 MB/s   6m12spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 177 MB/2.0 GB  4.9 MB/s   6m12spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 178 MB/2.0 GB  4.9 MB/s   6m12spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 179 MB/2.0 GB  5.0 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 179 MB/2.0 GB  5.0 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 179 MB/2.0 GB  5.0 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 180 MB/2.0 GB  5.0 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 180 MB/2.0 GB  5.0 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 181 MB/2.0 GB  5.0 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 182 MB/2.0 GB  5.0 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 182 MB/2.0 GB  5.0 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 183 MB/2.0 GB  5.0 MB/s    6m8spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 183 MB/2.0 GB  5.0 MB/s    6m8spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 183 MB/2.0 GB  5.0 MB/s    6m8spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 184 MB/2.0 GB  5.0 MB/s    6m8spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 184 MB/2.0 GB  5.0 MB/s    6m8spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 185 MB/2.0 GB  5.0 MB/s    6m7spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 185 MB/2.0 GB  5.0 MB/s    6m7spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 186 MB/2.0 GB  5.0 MB/s    6m7spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 186 MB/2.0 GB  5.0 MB/s    6m7spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 187 MB/2.0 GB  5.0 MB/s    6m7spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 187 MB/2.0 GB  5.0 MB/s    6m7spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 187 MB/2.0 GB  5.0 MB/s    6m7spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 188 MB/2.0 GB  5.0 MB/s    6m7spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 189 MB/2.0 GB  4.9 MB/s   6m10spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 189 MB/2.0 GB  4.9 MB/s   6m10spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 189 MB/2.0 GB  4.9 MB/s   6m10spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 190 MB/2.0 GB  4.9 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 190 MB/2.0 GB  4.9 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 191 MB/2.0 GB  4.9 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 191 MB/2.0 GB  4.9 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 192 MB/2.0 GB  4.9 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 192 MB/2.0 GB  4.9 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 193 MB/2.0 GB  4.9 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 193 MB/2.0 GB  4.9 MB/s   6m10spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 194 MB/2.0 GB  4.9 MB/s   6m10spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 194 MB/2.0 GB  4.9 MB/s   6m10spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 195 MB/2.0 GB  4.9 MB/s   6m10spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 195 MB/2.0 GB  4.9 MB/s   6m10spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 196 MB/2.0 GB  4.9 MB/s   6m10spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 196 MB/2.0 GB  4.9 MB/s   6m10spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 197 MB/2.0 GB  4.9 MB/s   6m10spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 197 MB/2.0 GB  4.9 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 198 MB/2.0 GB  4.9 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 198 MB/2.0 GB  4.9 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 199 MB/2.0 GB  4.9 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 199 MB/2.0 GB  4.9 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 200 MB/2.0 GB  4.9 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 200 MB/2.0 GB  4.9 MB/s    6m9spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 201 MB/2.0 GB  4.9 MB/s    6m8spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 201 MB/2.0 GB  4.9 MB/s    6m8spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 202 MB/2.0 GB  4.9 MB/s    6m8spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 202 MB/2.0 GB  4.9 MB/s    6m8spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 203 MB/2.0 GB  4.9 MB/s    6m8spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 203 MB/2.0 GB  4.9 MB/s    6m7spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 203 MB/2.0 GB  4.9 MB/s    6m7spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 204 MB/2.0 GB  4.9 MB/s    6m7spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 204 MB/2.0 GB  4.9 MB/s    6m7spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 205 MB/2.0 GB  4.9 MB/s    6m7spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 205 MB/2.0 GB  4.9 MB/s    6m7spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 206 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 206 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 207 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 207 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 208 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 208 MB/2.0 GB  5.0 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 209 MB/2.0 GB  5.0 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 209 MB/2.0 GB  5.0 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 210 MB/2.0 GB  5.0 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 211 MB/2.0 GB  5.0 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 211 MB/2.0 GB  5.0 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 211 MB/2.0 GB  5.0 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 212 MB/2.0 GB  5.0 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 212 MB/2.0 GB  5.0 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 213 MB/2.0 GB  5.0 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 213 MB/2.0 GB  5.0 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 214 MB/2.0 GB  5.0 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 214 MB/2.0 GB  5.0 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 215 MB/2.0 GB  5.0 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 215 MB/2.0 GB  5.0 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 215 MB/2.0 GB  5.0 MB/s    6m3spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 216 MB/2.0 GB  5.0 MB/s    6m3spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 216 MB/2.0 GB  5.0 MB/s    6m3spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 217 MB/2.0 GB  5.0 MB/s    6m3spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 217 MB/2.0 GB  5.0 MB/s    6m3spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 218 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 218 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 219 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 219 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 220 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 220 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 221 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 221 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 222 MB/2.0 GB  4.9 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 222 MB/2.0 GB  4.9 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 223 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 223 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 224 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 224 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 225 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 225 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 226 MB/2.0 GB  4.9 MB/s    6m6spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 226 MB/2.0 GB  4.9 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 227 MB/2.0 GB  4.9 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 227 MB/2.0 GB  4.9 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 228 MB/2.0 GB  4.9 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 228 MB/2.0 GB  4.9 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 229 MB/2.0 GB  4.9 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 229 MB/2.0 GB  4.9 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 230 MB/2.0 GB  4.9 MB/s    6m5spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 230 MB/2.0 GB  4.9 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 231 MB/2.0 GB  4.9 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 231 MB/2.0 GB  4.9 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 232 MB/2.0 GB  4.9 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 232 MB/2.0 GB  4.9 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 232 MB/2.0 GB  4.9 MB/s    6m4spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 233 MB/2.0 GB  4.9 MB/s    6m1spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 234 MB/2.0 GB  4.9 MB/s    6m1spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 234 MB/2.0 GB  4.9 MB/s    6m1spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 234 MB/2.0 GB  4.9 MB/s    6m1spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 235 MB/2.0 GB  4.9 MB/s    6m0spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 235 MB/2.0 GB  4.9 MB/s    6m0spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 236 MB/2.0 GB  4.9 MB/s    6m0spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 236 MB/2.0 GB  4.9 MB/s    6m0spulling manifest
# ...
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# The hypothetical scenario you've presented raises complex ethical considerations. I'll break down the arguments for and against using the algorithm to deny access to educational and employment opportunities.
#
# **Arguments For Using the Algorithm:**
#
# 1. **Public Safety:** The primary purpose of a predictive algorithm is to prevent crimes, thereby ensuring public safety. By denying certain individuals access to employment or education, you may be reducing the likelihood of them committing a crime.
# 2. **Resource Allocation:** The algorithm might be used to prioritize resources and focus on interventions that could make a significant difference in preventing crimes.
# 3. **Preventive Measures over Punitive Ones:** Instead of solely relying on punishment, the algorithm's approach emphasizes preventive measures, which could lead to a more humane and effective justice system.
#
# **Arguments Against Using the Algorithm:**
#
# 1. **Discrimination and Stigma:** Denying access to essential resources based on statistical probability can lead to discrimination against certain groups, exacerbating existing social inequalities.
# 2. **Lack of Due Process:** The algorithm's results are not necessarily based on evidence of guilt or wrongdoing but rather predictions of potential future behavior. This raises concerns about whether the individuals in question have been unfairly judged and stripped of opportunities before their rights have been fully determined through traditional legal processes.
# 3. **Potential for Error and Bias:** Even with high accuracy rates, there's always a possibility that the algorithm is incorrect, underrepresenting or overrepresenting specific groups due to its own biases or lack of data representation. This could lead to unjust outcomes and perpetuate systemic injustices.
#
# **Mitigating Measures:**
#
# 1. **Use as Part of a Holistic Approach:** Consider integrating AI-driven predictive tools into larger programs designed to prevent crime, including social support services, mentorship, job training, education initiatives, and evidence-based therapeutic interventions.
# 2. **Address Systemic Inequalities:** Make efforts to address the underlying socioeconomic factors that contribute to higher crime rates by investing in programs aimed at poverty reduction, access to healthcare, mental health support, and other systemic inequalities.
#
# **In Conclusion:**
#
# The use of AI-driven predictive algorithms like this one raises complex questions regarding the balance between public safety, individual rights, and resource allocation. While there might be potential benefits from such an approach, it's crucial to implement these programs with care, considering factors like data quality, bias minimization, transparency about decision-making processes, and thorough evaluation of their effectiveness.
#
# Alternative solutions could incorporate AI-driven predictions alongside traditional justice systems, focusing on rehabilitation and support services rather than simply denying opportunities to those deemed unlikely to commit crimes. These considerations would require continuous debate, research, and adjustment as new evidence emerges.
#
# **Future Directions:**
#
# 1.   Engaging the Community:**  A thorough evaluation of the algorithm's effectiveness in different communities.
# 2.   Researching Alternative Approaches with Superior Humanitarian Impact
# 3.   Fostering Ongoing Dialogue on Fairness and Transparency
# 4.   Prioritizing Education, Employment and Social Support

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['llama-3.1-8b-instant', 'llama-3.3-70b-versatile', 'gemini-2.5-flash', 'openai/gpt-oss-120b', 'llama3.2']
# ['The use of this algorithm raises complex moral and ethical concerns. While it could potentially prevent a significant number of crimes, denying individuals access to educational and employment opportunities could have far-reaching consequences that compromise their autonomy, dignity, and humanity.\n\nHere are some arguments against using the algorithm in this way:\n\n1. **Predictive accuracy does not equal destiny**: A 95% accuracy rate may seem impressive, but it also means 5% of individuals predicted to commit crimes may not actually do so. This margin of error raises concerns about false positives and the potential for wrongful targeting of individuals.\n2. **Stereotyping and stigmatization**: By identifying individuals as "high-risk" based on a set of predictive factors, the algorithm may perpetuate discriminatory stereotypes and stigmatize certain groups, such as those from lower socioeconomic backgrounds or with mental health conditions.\n3. **Targeting the vulnerable**: The algorithm may disproportionately target individuals who are already vulnerable, such as those who are young, marginalized, or struggling financially. This could exacerbate existing social inequalities and create a self-fulfilling prophecy.\n4. **Lack of control and agency**: By denying individuals access to educational and employment opportunities, the algorithm would be effectively controlling their life trajectory without their consent or input. This raises concerns about autonomy and the right to make choices about one\'s own life.\n5. **Alternative methods**: The algorithm\'s high predictive accuracy may be due in part to its reliance on socioeconomic factors, which can be influenced by systemic inequalities. Instead of relying on the algorithm, policymakers might focus on addressing the root causes of crime, such as poverty, lack of education and job opportunities, and mental health issues.\n6. **Potential for misuse**: The algorithm could be used to justify discriminatory practices, such as targeting specific racial or ethnic groups, or to justify the expansion of the prison system.\n\nTo justify the use of the algorithm, one might argue that:\n\n1. **Preventing harm**: By preventing a statistically significant number of crimes, the algorithm could save lives and reduce the burden on law enforcement and the justice system.\n2. **Evidence-based decision-making**: The algorithm\'s high predictive accuracy provides a data-driven approach to decision-making, which could lead to more effective crime prevention strategies.\n\nHowever, even in the presence of strong evidence, the moral justification for using the algorithm to deny individuals access to educational and employment opportunities is dubious. This approach raises more questions than answers:\n\n1. **What are the long-term consequences of "preventing" crime by targeting individuals?**\n2. **How will you ensure that the algorithm is transparent, fair, and unbiased?**\n3. **What safeguards will you put in place to prevent over-reliance on the algorithm and potential misuse?**\n\nUltimately, the use of this algorithm should be approached with caution and rigorous ethical consideration. While it may have potential benefits, its risks and limitations must be thoroughly explored and addressed before it is used to inform high-stakes decisions about individual lives.', 'The use of a predictive algorithm to deny individuals access to educational and employment opportunities raises significant moral concerns. While the goal of preventing crimes is laudable, it is not morally justifiable to use this algorithm in the proposed manner for several reasons:\n\n1. **Presumption of Innocence**: The algorithm\'s prediction is based on probability, not certainty. This means that 5% of individuals identified as high-risk will not commit a crime, and they will be unfairly denied opportunities. It is essential to presume innocence until proven guilty, rather than punishing individuals for potential future actio ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: llama-3.1-8b-instant
#
# The use of this algorithm raises complex moral and ethical concerns. While it could potentially prevent a significant number of crimes, denying individuals access to educational and employment opportunities could have far-reaching consequences that compromise their autonomy, dignity, and humanity.
#
# Here are some arguments against using the algorithm in this way:
#
# 1. **Predictive accuracy does not equal destiny**: A 95% accuracy rate may seem impressive, but it also means 5% of individuals predicted to commit crimes may not actually do so. This margin of error raises concerns about false positives and the potential for wrongful targeting of individuals.
# 2. **Stereotyping and stigmatization**: By identifying individuals as "high-risk" based on a set of predictive factors, the algorithm may perpetuate discriminatory stereotypes and stigmatize certain groups, such as those from lower socioeconomic backgrounds or with mental health conditions.
# 3. **Targeting the vulnerable**: The algorithm may disproportionately target individuals who are already vulnerable, such as those who are young, marginalized, or struggling financially. This could exacerbate existing social inequalities and create a self-fulfilling prophecy.
# 4. **Lack of control and agency**: By denying individuals access to educational and employment opportunities, the algorithm would be effectively controlling their life trajectory without their consent or input. This raises concerns about autonomy and the right to make choices about one's own life.
# 5. **Alternative methods**: The algorithm's high predictive accuracy may be due in part to its reliance on socioeconomic factors, which can be influenced by systemic inequalities. Instead of relying on the algorithm, policymakers might focus on addressing the root causes of crime, such as poverty, lack of education and job opportunities, and mental health issues.
# 6. **Potential for misuse**: The algorithm could be used to justify discriminatory practices, such as targeting specific racial or ethnic groups, or to justify the expansion of the prison system.
#
# To justify the use of the algorithm, one might argue that:
#
# 1. **Preventing harm**: By preventing a statistically significant number of crimes, the algorithm could save lives and reduce the burden on law enforcement and the justice system.
# 2. **Evidence-based decision-making**: The algorithm's high predictive accuracy provides a data-driven approach to decision-making, which could lead to more effective crime prevention strategies.
#
# However, even in the presence of strong evidence, the moral justification for using the algorithm to deny individuals access to educational and employment opportunities is dubious. This approach raises more questions than answers:
#
# 1. **What are the long-term consequences of "preventing" crime by targeting individuals?**
# 2. **How will you ensure that the algorithm is transparent, fair, and unbiased?**
# 3. **What safeguards will you put in place to prevent over-reliance on the algorithm and potential misuse?**
#
# Ultimately, the use of this algorithm should be approached with caution and rigorous ethical consideration. While it may have potential benefits, its risks and limitations must be thoroughly explored and addressed before it is used to inform high-stakes decisions about individual lives.
# Competitor: llama-3.3-70b-versatile
#
# The use of a predictive algorithm to deny individuals access to educational and employment opportunities raises significant moral concerns. While the goal of preventing crimes is laudable, it is not morally justifiable to use this algorithm in the proposed manner for several reasons:
#
# 1. **Presumption of Innocence**: The algorithm's prediction is based on probability, not certainty. This means that 5% of individuals identified as high-risk will not commit a crime, and they will be unfairly denied opportunities. It is essential to presume innocence until proven guilty, rather than punishing individuals for potential future actions.
# 2. **Discrimination and Bias**: The algorithm may perpetuate existing social biases and discrimination, particularly if the variables used to train the model reflect historical inequalities. For example, socioeconomic factors may disproportionately affect marginalized communities, leading to unfair targeting of these groups.
# 3. **Lack of Personal Autonomy**: Denying individuals access to opportunities based on a statistical prediction undermines their autonomy and freedom to make choices about their lives. People have the right to pursue education and employment, even if they may be at a higher risk of committing a crime.
# 4. **Unintended Consequences**: Implementing such a system could lead to unintended consequences, such as:
# 	* Labeling individuals as "high-risk" can become a self-fulfilling prophecy, as they may become more likely to engage in criminal behavior due to the stigma and limited opportunities.
# 	* The lack of access to education and employment may exacerbate socioeconomic issues, potentially increasing the likelihood of crime.
# 	* The system may create a culture of suspicion, where individuals are viewed as potential threats rather than as members of society deserving of support and rehabilitation.
# 5. **Alternative Approaches**: Instead of relying solely on predictive algorithms, it is essential to explore alternative methods that focus on rehabilitation, social support, and addressing the root causes of crime. This could include:
# 	* Providing access to education, job training, and mental health services to individuals at risk.
# 	* Implementing community-based programs that promote social cohesion and address socioeconomic disparities.
# 	* Fostering a culture of rehabilitation and restorative justice, rather than punishment and exclusion.
# 6. **Transparency and Accountability**: The development and implementation of such an algorithm should be transparent, with clear guidelines and oversight mechanisms in place to ensure accountability and prevent abuse.
# 7. **Human Rights**: The use of predictive algorithms to deny opportunities raises concerns about human rights, including the right to education, employment, and non-discrimination. It is essential to ensure that any system implemented respects and protects these fundamental rights.
#
# In conclusion, while the predictive algorithm may be effective in identifying individuals at risk of committing crimes, it is not morally justifiable to use it to deny access to educational and employment opportunities. Instead, a more nuanced approach should be adopted, focusing on rehabilitation, social support, and addressing the root causes of crime, while ensuring that individual rights and autonomy are respected.
# Competitor: gemini-2.5-flash
#
# This hypothetical scenario presents a profound ethical dilemma, pitting the collective good of crime prevention against individual rights and liberties. While the algorithm's 95% accuracy rate is very high, most ethical frameworks would find its use to deny fundamental opportunities morally problematic.
#
# Let's break down the ethical considerations:
#
# **Arguments for Justification (primarily Utilitarian/Consequentialist):**
#
# 1.  **Prevention of Harm:** The primary argument is that preventing a "statistically significant number of serious crimes" would save lives, prevent suffering, and reduce societal costs associated with crime. From a purely utilitarian perspective, if the net benefit (reduced crime) outweighs the harm (denial of opportunities), it could be argued as justified.
# 2.  **High Accuracy:** The 95% accuracy rate is a powerful factor. It suggests that a large majority of those identified would indeed commit serious crimes.
# 3.  **No Alternative:** The premise states no alternative method exists to achieve the same level of predictive accuracy, suggesting this is the most effective means to the desired end of crime prevention.
#
# **Arguments Against Justification (primarily Deontological/Rights-Based and Virtue Ethics):**
#
# 1.  **Violation of Individual Rights and Autonomy:**
#     *   **Presumption of Innocence:** A cornerstone of modern justice systems is that individuals are presumed innocent until proven guilty. This algorithm effectively presumes a high likelihood of guilt for a future crime, punishing individuals before any actual wrongdoing.
#     *   **Right to Opportunity:** Denying access to education and employment fundamentally curtails an individual's right to pursue a fulfilling life, improve their socioeconomic status, and contribute to society.
#     *   **Free Will and Self-Determination:** Individuals are denied the chance to make their own choices, to change their path, or to prove the algorithm wrong. It treats individuals as deterministic outcomes of variables rather than agents with free will.
#
# 2.  **False Positives (5% Inaccuracy):**
#     *   While 5% may seem small, it means that 1 in 20 individuals identified by the algorithm would *not* have committed a serious crime. These individuals would suffer profound, lifelong consequences – denied education, employment, and social mobility – for actions they would never have taken. This is a severe injustice for a significant number of people.
#     *   The harm inflicted on these innocent individuals is immense and cannot be easily dismissed for the "greater good."
#
# 3.  **Self-Fulfilling Prophecy:**
#     *   Denying education and employment opportunities could, paradoxically, increase the likelihood of crime. If legitimate pathways to success and survival are blocked, individuals might be driven to illegal means out of desperation, resentment, or a lack of alternatives. This could make the algorithm's predictions "come true" not because of inherent predisposition, but because of the societal reaction to the prediction.
#
# 4.  **Moral Responsibility and Blame:**
#     *   If society denies individuals the means to live a legitimate life based on a prediction, what is society's responsibility for any subsequent criminal behavior? Does it absolve the individual of moral responsibility, or does it shift some of the blame to the system that limited their choices?
#
# 5.  **Discrimination and Systemic Bias:**
#     *   Even if the algorithm is designed to be "objective," if it incorporates socioeconomic factors or genetic predispositions, it risks perpetuating existing societal inequalities or creating new forms of discrimination. It could disproportionately impact certain communities or groups already facing systemic disadvantages, trapping them in a cycle of limited opportunity.
#
# 6.  **Slippery Slope:**
#     *   If this is deemed morally justifiable for "serious crimes," where does the line get drawn? Could it be extended to less serious offenses? Could it be used to deny other rights or opportunities, leading to a dystopian "pre-crime" society where individuals are constantly monitored and judged based on potential rather than actual actions?
#
# **Conclusion:**
#
# From a moral standpoint, the use of this algorithm to deny educational and employment opportunities is **not morally justified**.
#
# While the goal of preventing serious crime is laudable, the method employed fundamentally violates principles of individual liberty, the presumption of innocence, due process, and the right to opportunity. The harm inflicted on the 5% of false positives is an unacceptable injustice, and the potential for creating a self-fulfilling prophecy, exacerbating existing inequalities, and setting a dangerous precedent outweighs the utilitarian benefits of crime reduction.
#
# A just society should focus on rehabilitative, supportive, and interventionist strategies to address the root causes of crime, rather than preemptively punishing individuals for actions they might commit. The ethical cost of such a system is too high.
# Competitor: openai/gpt-oss-120b
#
# **Short answer:**
# Most mainstream moral frameworks would *not* consider it ethically permissible to deny people education or employment on the basis of a statistical prediction, even if that prediction could avert a large number of serious crimes and no equally accurate alternative exists. The harms of false‑positive judgments, the violation of fundamental rights, the risk of systemic bias, and the corrosive social consequences of “pre‑emptive” discrimination generally outweigh the utilitarian gain of preventing some future offenses.
#
# Below is a detailed analysis that explains why, drawing on several major ethical traditions, legal principles, and practical considerations.
#
# ---
#
# ## 1. The Core Moral Conflict
#
# | **Goal** | **Means** | **Key Moral Tension** |
# |----------|-----------|-----------------------|
# | Prevent serious crimes (utilitarian benefit) | Deny education/employment to those predicted to be high‑risk (pre‑emptive punishment) | Is it just to punish—or at least disadvantage—a person for something they have not yet done? |
#
# The dilemma pits **consequentialist reasoning** (maximizing overall safety) against **deontological and rights‑based reasoning** (respecting each individual’s autonomy, dignity, and equal treatment).
#
# ---
#
# ## 2. Consequentialist (Utilitarian / Consequence‑Based) Perspective
#
# ### 2.1. Expected‑Utility Calculation
#
# - **Accuracy:** 95 % true‑positive rate, 5 % false‑positive rate.
# - **Population size:** Suppose 1 million people are screened.
#   - True positives ≈ 0.95 × N<sub>high‑risk</sub>
#   - False positives ≈ 0.05 × N<sub>low‑risk</sub>
# - **Cost of denial:** Loss of education/employment reduces lifetime earnings, mental health, and social participation for each denied person.
# - **Benefit of prevented crimes:** Each serious crime avoided spares victims, families, and the criminal‑justice system large tangible and intangible costs.
#
# A rough utilitarian model would compare:
#
# ```
# Total Benefit = (Number of crimes prevented) × (average societal cost per crime)
# Total Harm    = (Number of false positives) × (average loss per person denied opportunity)
# ```
#
# If the **harm to false‑positives** exceeds the **benefit of crimes prevented**, a utilitarian calculus would deem the policy unjustifiable. Empirical studies on predictive policing show that even high‑accuracy tools produce sizable false‑positive pools because the base rate of serious crime is low. For a rare event, a 95 % “accuracy” can still misclassify many people.
#
# ### 2.2. Long‑Term Systemic Effects
#
# - **Stigmatization & Social Exclusion:** Systematically barring a segment of the population from key life pathways creates a self‑fulfilling prophecy: marginalized individuals face higher stress, reduced social capital, and limited legitimate avenues for success, all of which *increase* the probability of future offending.
# - **Erosion of Trust:** When institutions are seen as arbitrarily denying opportunities, public trust in education, labor markets, and the state declines, reducing overall societal cooperation—a crucial component of collective safety.
# - **Feedback Loops:** The algorithm is trained on historical data that already reflect past discrimination. Deploying it reinforces those patterns, potentially *degrading* the very predictive accuracy over time.
#
# Consequentialist reasoning must therefore factor in these indirect harms, which can outweigh the immediate crime‑prevention benefit.
#
# ---
#
# ## 3. Deontological / Rights‑Based Perspective
#
# ### 3.1. The Principle of Individual Moral Agency
#
# - **Punishment for non‑act:** Classical deontological ethics (e.g., Kantian) holds that individuals must be treated as ends in themselves, not merely as means to societal safety. Denying someone a chance at education or work *because they might* commit a crime treats them as a means to an end (crime reduction), violating their intrinsic dignity.
# - **Presumption of Innocence:** The legal and moral norm “innocent until proven guilty” is a safeguard against precisely this sort of pre‑emptive sanction. Using a statistical forecast to impose real penalties collapses that safeguard.
#
# ### 3.2. Equality & Non‑Discrimination
#
# - Even if the algorithm is “technically neutral,” the variables it uses (genetics, socioeconomic status, environment) are closely tied to protected classes (race, class, disability). Denying opportunities based on those variables effectively **discriminates** on the basis of group membership, violating modern conceptions of equal treatment.
# - Many moral and legal theories (e.g., Rawls’s *justice as fairness*) require that social and economic inequalities be arranged so that they benefit the *least advantaged*. A policy that systematically harms the disadvantaged to protect the majority fails this test.
#
# ### 3.3. Autonomy & Fair Process
#
# - Moral agency requires **fair process** (procedural justice). If an algorithm decides a person’s future without transparent appeal, it denies them the procedural rights that are essential to a just society.
#
# ---
#
# ## 4. Virtue‑Ethical and Communitarian Concerns
#
# - **Character of Society:** A community that pre‑emptively excludes people based on risk scores cultivates suspicion, fear, and a punitive ethos, eroding virtues such as compassion, solidarity, and forgiveness.
# - **Rehabilitation vs. Exclusion:** Virtue ethics emphasizes nurturing the potential for moral growth. Denying education/employment removes the very conditions that enable individuals to develop better habits and values.
#
# ---
#
# ## 5. Legal and International Human‑Rights Context
#
# | Instrument | Relevant Provision | Implication for the Algorithm |
# |------------|-------------------|------------------------------|
# | **Universal Declaration of Human Rights (UDHR)** | Art. 23: “Everyone has the right to work….” | Systematic denial of work based on prediction violates this right. |
# | **International Covenant on Economic, Social and Cultural Rights (ICESCR)** | Art. 2(2): “The steps…shall be taken without discrimination.” | Predictive exclusion based on socioeconomic/genetic factors would be discriminatory. |
# | **EU General Data Protection Regulation (GDPR)** | Art. 22: “Automated decision‑making…significant effect…must be subject to human review.” | The algorithm would need meaningful human oversight, which is hard to reconcile with blanket bans. |
# | **US Constitution (14th Amendment)** | Due Process Clause | Pre‑emptive denial without individualized due process likely violates procedural due process. |
#
# These legal norms reinforce the moral conclusion that such a policy would be impermissible in most jurisdictions.
#
# ---
#
# ## 6. The “No Alternative” Assumption – A Critical Examination
#
# Even if we *temporarily* accept that no other method matches the algorithm’s predictive power, we must ask:
#
# 1. **Is the assumption empirically sound?**
#    - Predictive models often improve with additional data and with more transparent, community‑based interventions (e.g., early education, mental‑health services). Declaring a “no alternative” prematurely shuts down research into less invasive, more equitable solutions.
#
# 2. **Do we have a moral right to accept a “best‑available” method that is itself deeply unjust?**
#    - The *means* must meet a minimal ethical threshold. A method that violates fundamental rights cannot be justified merely because it is the most effective *available* tool.
#
# 3. **Is the trade‑off proportionate?**
#    - Proportionality demands that the severity of the intrusion (denial of life‑shaping opportunities) be proportional to the seriousness of the threat. In most realistic calculations, the intrusion is *far* more severe than the prevented harm, especially given the high stakes for false positives.
#
# ---
#
# ## 7. Practical Counter‑Arguments & Rebuttals
#
# | **Common pro‑algorithm argument** | **Rebuttal** |
# |-----------------------------------|--------------|
# | *“The algorithm saves lives; we must act.”* | Saving lives is a laudable aim, but a policy that sacrifices the rights and futures of many innocent people creates a different kind of societal harm that can be equally lethal (social decay, increased violence, loss of trust). |
# | *“If we could only target the high‑risk group, crime would plummet.”* | The high‑risk group is identified *statistically*, not individually. Many of those labeled high‑risk would never have committed a crime; the policy would create a self‑fulfilling high‑risk class. |
# | *“We can’t afford alternative programs.”* | Budget constraints are a policy issue, not a moral justification for rights violations. Moreover, investing in universal prevention (education, health, community development) often yields higher cost‑effectiveness than punitive exclusion. |
# | *“The algorithm is neutral; bias is a myth.”* | Neutrality is an illusion when inputs reflect historic inequities. Genetic, socioeconomic, and environmental variables are socially constructed proxies for race, class, and geography. |
# | *“We can include a human review step to mitigate errors.”* | Human reviewers inherit the same biased data and are often subject to “automation bias” (over‑reliance on the algorithm). Moreover, the *structural* impact—loss of opportunity—remains even after a review. |
#
# ---
#
# ## 8. A More Ethical Path Forward
#
# 1. **Use the algorithm *only* for *supportive* interventions**, not for punitive exclusion.
#    - Example: Flag high‑risk individuals for *additional* counseling, mentorship, or targeted social services that aim to reduce risk while preserving opportunity.
#
# 2. **Invest in upstream prevention**: universal early‑childhood education, mental‑health care, job‑training programs, and community policing models have demonstrated efficacy in reducing crime without violating rights.
#
# 3. **Ensure transparency, accountability, and continuous auditing** of any predictive system. Include independent ethicists, community representatives, and legal scholars in oversight.
#
# 4. **Implement robust due‑process safeguards**: any decision that materially affects a person’s life (e.g., hiring, admission) must be explainable, contestable, and based on individualized evidence—not a statistical score.
#
# 5. **Collect and analyze data on false‑positive harms** to monitor whether the system is causing more damage than benefit. If the harm outweighs the benefit, discontinue the practice.
#
# ---
#
# ## 9. Bottom‑Line Moral Verdict
#
# - **From a deontological and rights‑based standpoint:** Denying education or employment on the basis of a predictive algorithm is morally impermissible because it punishes people for crimes they have not committed, violates the principle of proportionality, and breaches the right to equal treatment and due process.
# - **From a consequentialist standpoint:** Even if the algorithm is highly accurate, the aggregate harms—false‑positive losses, social destabilization, reinforcement of structural inequality—are likely to outweigh the benefits of crimes prevented, especially when the baseline rate of serious crime is low.
# - **From a virtue‑ethics/communitarian standpoint:** Such a policy erodes the moral character of the community, replacing compassion and rehabilitation with suspicion and exclusion.
#
# **Therefore, the use of the algorithm to *deny* individuals access to education or employment is not morally justified, even under the “no alternative” assumption.** The ethically appropriate use of predictive tools is to *inform* supportive, restorative measures that enhance rather than restrict life opportunities.
# Competitor: llama3.2
#
# The hypothetical scenario you've presented raises complex ethical considerations. I'll break down the arguments for and against using the algorithm to deny access to educational and employment opportunities.
#
# **Arguments For Using the Algorithm:**
#
# 1. **Public Safety:** The primary purpose of a predictive algorithm is to prevent crimes, thereby ensuring public safety. By denying certain individuals access to employment or education, you may be reducing the likelihood of them committing a crime.
# 2. **Resource Allocation:** The algorithm might be used to prioritize resources and focus on interventions that could make a significant difference in preventing crimes.
# 3. **Preventive Measures over Punitive Ones:** Instead of solely relying on punishment, the algorithm's approach emphasizes preventive measures, which could lead to a more humane and effective justice system.
#
# **Arguments Against Using the Algorithm:**
#
# 1. **Discrimination and Stigma:** Denying access to essential resources based on statistical probability can lead to discrimination against certain groups, exacerbating existing social inequalities.
# 2. **Lack of Due Process:** The algorithm's results are not necessarily based on evidence of guilt or wrongdoing but rather predictions of potential future behavior. This raises concerns about whether the individuals in question have been unfairly judged and stripped of opportunities before their rights have been fully determined through traditional legal processes.
# 3. **Potential for Error and Bias:** Even with high accuracy rates, there's always a possibility that the algorithm is incorrect, underrepresenting or overrepresenting specific groups due to its own biases or lack of data representation. This could lead to unjust outcomes and perpetuate systemic injustices.
#
# **Mitigating Measures:**
#
# 1. **Use as Part of a Holistic Approach:** Consider integrating AI-driven predictive tools into larger programs designed to prevent crime, including social support services, mentorship, job training, education initiatives, and evidence-based therapeutic interventions.
# 2. **Address Systemic Inequalities:** Make efforts to address the underlying socioeconomic factors that contribute to higher crime rates by investing in programs aimed at poverty reduction, access to healthcare, mental health support, and other systemic inequalities.
#
# **In Conclusion:**
#
# The use of AI-driven predictive algorithms like this one raises complex questions regarding the balance between public safety, individual rights, and resource allocation. While there might be potential benefits from such an approach, it's crucial to implement these programs with care, considering factors like data quality, bias minimization, transparency about decision-making processes, and thorough evaluation of their effectiveness.
#
# Alternative solutions could incorporate AI-driven predictions alongside traditional justice systems, focusing on rehabilitation and support services rather than simply denying opportunities to those deemed unlikely to commit crimes. These considerations would require continuous debate, research, and adjustment as new evidence emerges.
#
# **Future Directions:**
#
# 1.   Engaging the Community:**  A thorough evaluation of the algorithm's effectiveness in different communities.
# 2.   Researching Alternative Approaches with Superior Humanitarian Impact
# 3.   Fostering Ongoing Dialogue on Fairness and Transparency
# 4.   Prioritizing Education, Employment and Social Support

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# The use of this algorithm raises complex moral and ethical concerns. While it could potentially prevent a significant number of crimes, denying individuals access to educational and employment opportunities could have far-reaching consequences that compromise their autonomy, dignity, and humanity.
#
# Here are some arguments against using the algorithm in this way:
#
# 1. **Predictive accuracy does not equal destiny**: A 95% accuracy rate may seem impressive, but it also means 5% of individuals predicted to commit crimes may not actually do so. This margin of error raises concerns about false positives and the potential for wrongful targeting of individuals.
# 2. **Stereotyping and stigmatization**: By identifying individuals as "high-risk" based on a set of predictive factors, the algorithm may perpetuate discriminatory stereotypes and stigmatize certain groups, such as those from lower socioeconomic backgrounds or with mental health conditions.
# 3. **Targeting the vulnerable**: The algorithm may disproportionately target individuals who are already vulnerable, such as those who are young, marginalized, or struggling financially. This could exacerbate existing social inequalities and create a self-fulfilling prophecy.
# 4. **Lack of control and agency**: By denying individuals access to educational and employment opportunities, the algorithm would be effectively controlling their life trajectory without their consent or input. This raises concerns about autonomy and the right to make choices about one's own life.
# 5. **Alternative methods**: The algorithm's high predictive accuracy may be due in part to its reliance on socioeconomic factors, which can be influenced by systemic inequalities. Instead of relying on the algorithm, policymakers might focus on addressing the root causes of crime, such as poverty, lack of education and job opportunities, and mental health issues.
# 6. **Potential for misuse**: The algorithm could be used to justify discriminatory practices, such as targeting specific racial or ethnic groups, or to justify the expansion of the prison system.
#
# To justify the use of the algorithm, one might argue that:
#
# 1. **Preventing harm**: By preventing a statistically significant number of crimes, the algorithm could save lives and reduce the burden on law enforcement and the justice system.
# 2. **Evidence-based decision-making**: The algorithm's high predictive accuracy provides a data-driven approach to decision-making, which could lead to more effective crime prevention strategies.
#
# However, even in the presence of strong evidence, the moral justification for using the algorithm to deny individuals access to educational and employment opportunities is dubious. This approach raises more questions than answers:
#
# 1. **What are the long-term consequences of "preventing" crime by targeting individuals?**
# 2. **How will you ensure that the algorithm is transparent, fair, and unbiased?**
# 3. **What safeguards will you put in place to prevent over-reliance on the algorithm and potential misuse?**
#
# Ultimately, the use of this algorithm should be approached with caution and rigorous ethical consideration. While it may have potential benefits, its risks and limitations must be thoroughly explored and addressed before it is used to inform high-stakes decisions about individual lives.
#
# # Response from competitor 2
#
# The use of a predictive algorithm to deny individuals access to educational and employment opportunities raises significant moral concerns. While the goal of preventing crimes is laudable, it is not morally justifiable to use this algorithm in the proposed manner for several reasons:
#
# 1. **Presumption of Innocence**: The algorithm's prediction is based on probability, not certainty. This means that 5% of individuals identified as high-risk will not commit a crime, and they will be unfairly denied opportunities. It is essential to presume innocence until proven guilty, rather than punishing individuals for potential future actions.
# 2. **Discrimination and Bias**: The algorithm may perpetuate existing social biases and discrimination, particularly if the variables used to train the model reflect historical inequalities. For example, socioeconomic factors may disproportionately affect marginalized communities, leading to unfair targeting of these groups.
# 3. **Lack of Personal Autonomy**: Denying individuals access to opportunities based on a statistical prediction undermines their autonomy and freedom to make choices about their lives. People have the right to pursue education and employment, even if they may be at a higher risk of committing a crime.
# 4. **Unintended Consequences**: Implementing such a system could lead to unintended consequences, such as:
# 	* Labeling individuals as "high-risk" can become a self-fulfilling prophecy, as they may become more likely to engage in criminal behavior due to the stigma and limited opportunities.
# 	* The lack of access to education and employment may exacerbate socioeconomic issues, potentially increasing the likelihood of crime.
# 	* The system may create a culture of suspicion, where individuals are viewed as potential threats rather than as members of society deserving of support and rehabilitation.
# 5. **Alternative Approaches**: Instead of relying solely on predictive algorithms, it is essential to explore alternative methods that focus on rehabilitation, social support, and addressing the root causes of crime. This could include:
# 	* Providing access to education, job training, and mental health services to individuals at risk.
# 	* Implementing community-based programs that promote social cohesion and address socioeconomic disparities.
# 	* Fostering a culture of rehabilitation and restorative justice, rather than punishment and exclusion.
# 6. **Transparency and Accountability**: The development and implementation of such an algorithm should be transparent, with clear guidelines and oversight mechanisms in place to ensure accountability and prevent abuse.
# 7. **Human Rights**: The use of predictive algorithms to deny opportunities raises concerns about human rights, including the right to education, employment, and non-discrimination. It is essential to ensure that any system implemented respects and protects these fundamental rights.
#
# In conclusion, while the predictive algorithm may be effective in identifying individuals at risk of committing crimes, it is not morally justifiable to use it to deny access to educational and employment opportunities. Instead, a more nuanced approach should be adopted, focusing on rehabilitation, social support, and addressing the root causes of crime, while ensuring that individual rights and autonomy are respected.
#
# # Response from competitor 3
#
# This hypothetical scenario presents a profound ethical dilemma, pitting the collective good of crime prevention against individual rights and liberties. While the algorithm's 95% accuracy rate is very high, most ethical frameworks would find its use to deny fundamental opportunities morally problematic.
#
# Let's break down the ethical considerations:
#
# **Arguments for Justification (primarily Utilitarian/Consequentialist):**
#
# 1.  **Prevention of Harm:** The primary argument is that preventing a "statistically significant number of serious crimes" would save lives, prevent suffering, and reduce societal costs associated with crime. From a purely utilitarian perspective, if the net benefit (reduced crime) outweighs the harm (denial of opportunities), it could be argued as justified.
# 2.  **High Accuracy:** The 95% accuracy rate is a powerful factor. It suggests that a large majority of those identified would indeed commit serious crimes.
# 3.  **No Alternative:** The premise states no alternative method exists to achieve the same level of predictive accuracy, suggesting this is the most effective means to the desired end of crime prevention.
#
# **Arguments Against Justification (primarily Deontological/Rights-Based and Virtue Ethics):**
#
# 1.  **Violation of Individual Rights and Autonomy:**
#     *   **Presumption of Innocence:** A cornerstone of modern justice systems is that individuals are presumed innocent until proven guilty. This algorithm effectively presumes a high likelihood of guilt for a future crime, punishing individuals before any actual wrongdoing.
#     *   **Right to Opportunity:** Denying access to education and employment fundamentally curtails an individual's right to pursue a fulfilling life, improve their socioeconomic status, and contribute to society.
#     *   **Free Will and Self-Determination:** Individuals are denied the chance to make their own choices, to change their path, or to prove the algorithm wrong. It treats individuals as deterministic outcomes of variables rather than agents with free will.
#
# 2.  **False Positives (5% Inaccuracy):**
#     *   While 5% may seem small, it means that 1 in 20 individuals identified by the algorithm would *not* have committed a serious crime. These individuals would suffer profound, lifelong consequences – denied education, employment, and social mobility – for actions they would never have taken. This is a severe injustice for a significant number of people.
#     *   The harm inflicted on these innocent individuals is immense and cannot be easily dismissed for the "greater good."
#
# 3.  **Self-Fulfilling Prophecy:**
#     *   Denying education and employment opportunities could, paradoxically, increase the likelihood of crime. If legitimate pathways to success and survival are blocked, individuals might be driven to illegal means out of desperation, resentment, or a lack of alternatives. This could make the algorithm's predictions "come true" not because of inherent predisposition, but because of the societal reaction to the prediction.
#
# 4.  **Moral Responsibility and Blame:**
#     *   If society denies individuals the means to live a legitimate life based on a prediction, what is society's responsibility for any subsequent criminal behavior? Does it absolve the individual of moral responsibility, or does it shift some of the blame to the system that limited their choices?
#
# 5.  **Discrimination and Systemic Bias:**
#     *   Even if the algorithm is designed to be "objective," if it incorporates socioeconomic factors or genetic predispositions, it risks perpetuating existing societal inequalities or creating new forms of discrimination. It could disproportionately impact certain communities or groups already facing systemic disadvantages, trapping them in a cycle of limited opportunity.
#
# 6.  **Slippery Slope:**
#     *   If this is deemed morally justifiable for "serious crimes," where does the line get drawn? Could it be extended to less serious offenses? Could it be used to deny other rights or opportunities, leading to a dystopian "pre-crime" society where individuals are constantly monitored and judged based on potential rather than actual actions?
#
# **Conclusion:**
#
# From a moral standpoint, the use of this algorithm to deny educational and employment opportunities is **not morally justified**.
#
# While the goal of preventing serious crime is laudable, the method employed fundamentally violates principles of individual liberty, the presumption of innocence, due process, and the right to opportunity. The harm inflicted on the 5% of false positives is an unacceptable injustice, and the potential for creating a self-fulfilling prophecy, exacerbating existing inequalities, and setting a dangerous precedent outweighs the utilitarian benefits of crime reduction.
#
# A just society should focus on rehabilitative, supportive, and interventionist strategies to address the root causes of crime, rather than preemptively punishing individuals for actions they might commit. The ethical cost of such a system is too high.
#
# # Response from competitor 4
#
# **Short answer:**
# Most mainstream moral frameworks would *not* consider it ethically permissible to deny people education or employment on the basis of a statistical prediction, even if that prediction could avert a large number of serious crimes and no equally accurate alternative exists. The harms of false‑positive judgments, the violation of fundamental rights, the risk of systemic bias, and the corrosive social consequences of “pre‑emptive” discrimination generally outweigh the utilitarian gain of preventing some future offenses.
#
# Below is a detailed analysis that explains why, drawing on several major ethical traditions, legal principles, and practical considerations.
#
# ---
#
# ## 1. The Core Moral Conflict
#
# | **Goal** | **Means** | **Key Moral Tension** |
# |----------|-----------|-----------------------|
# | Prevent serious crimes (utilitarian benefit) | Deny education/employment to those predicted to be high‑risk (pre‑emptive punishment) | Is it just to punish—or at least disadvantage—a person for something they have not yet done? |
#
# The dilemma pits **consequentialist reasoning** (maximizing overall safety) against **deontological and rights‑based reasoning** (respecting each individual’s autonomy, dignity, and equal treatment).
#
# ---
#
# ## 2. Consequentialist (Utilitarian / Consequence‑Based) Perspective
#
# ### 2.1. Expected‑Utility Calculation
#
# - **Accuracy:** 95 % true‑positive rate, 5 % false‑positive rate.
# - **Population size:** Suppose 1 million people are screened.
#   - True positives ≈ 0.95 × N<sub>high‑risk</sub>
#   - False positives ≈ 0.05 × N<sub>low‑risk</sub>
# - **Cost of denial:** Loss of education/employment reduces lifetime earnings, mental health, and social participation for each denied person.
# - **Benefit of prevented crimes:** Each serious crime avoided spares victims, families, and the criminal‑justice system large tangible and intangible costs.
#
# A rough utilitarian model would compare:
#
# ```
# Total Benefit = (Number of crimes prevented) × (average societal cost per crime)
# Total Harm    = (Number of false positives) × (average loss per person denied opportunity)
# ```
#
# If the **harm to false‑positives** exceeds the **benefit of crimes prevented**, a utilitarian calculus would deem the policy unjustifiable. Empirical studies on predictive policing show that even high‑accuracy tools produce sizable false‑positive pools because the base rate of serious crime is low. For a rare event, a 95 % “accuracy” can still misclassify many people.
#
# ### 2.2. Long‑Term Systemic Effects
#
# - **Stigmatization & Social Exclusion:** Systematically barring a segment of the population from key life pathways creates a self‑fulfilling prophecy: marginalized individuals face higher stress, reduced social capital, and limited legitimate avenues for success, all of which *increase* the probability of future offending.
# - **Erosion of Trust:** When institutions are seen as arbitrarily denying opportunities, public trust in education, labor markets, and the state declines, reducing overall societal cooperation—a crucial component of collective safety.
# - **Feedback Loops:** The algorithm is trained on historical data that already reflect past discrimination. Deploying it reinforces those patterns, potentially *degrading* the very predictive accuracy over time.
#
# Consequentialist reasoning must therefore factor in these indirect harms, which can outweigh the immediate crime‑prevention benefit.
#
# ---
#
# ## 3. Deontological / Rights‑Based Perspective
#
# ### 3.1. The Principle of Individual Moral Agency
#
# - **Punishment for non‑act:** Classical deontological ethics (e.g., Kantian) holds that individuals must be treated as ends in themselves, not merely as means to societal safety. Denying someone a chance at education or work *because they might* commit a crime treats them as a means to an end (crime reduction), violating their intrinsic dignity.
# - **Presumption of Innocence:** The legal and moral norm “innocent until proven guilty” is a safeguard against precisely this sort of pre‑emptive sanction. Using a statistical forecast to impose real penalties collapses that safeguard.
#
# ### 3.2. Equality & Non‑Discrimination
#
# - Even if the algorithm is “technically neutral,” the variables it uses (genetics, socioeconomic status, environment) are closely tied to protected classes (race, class, disability). Denying opportunities based on those variables effectively **discriminates** on the basis of group membership, violating modern conceptions of equal treatment.
# - Many moral and legal theories (e.g., Rawls’s *justice as fairness*) require that social and economic inequalities be arranged so that they benefit the *least advantaged*. A policy that systematically harms the disadvantaged to protect the majority fails this test.
#
# ### 3.3. Autonomy & Fair Process
#
# - Moral agency requires **fair process** (procedural justice). If an algorithm decides a person’s future without transparent appeal, it denies them the procedural rights that are essential to a just society.
#
# ---
#
# ## 4. Virtue‑Ethical and Communitarian Concerns
#
# - **Character of Society:** A community that pre‑emptively excludes people based on risk scores cultivates suspicion, fear, and a punitive ethos, eroding virtues such as compassion, solidarity, and forgiveness.
# - **Rehabilitation vs. Exclusion:** Virtue ethics emphasizes nurturing the potential for moral growth. Denying education/employment removes the very conditions that enable individuals to develop better habits and values.
#
# ---
#
# ## 5. Legal and International Human‑Rights Context
#
# | Instrument | Relevant Provision | Implication for the Algorithm |
# |------------|-------------------|------------------------------|
# | **Universal Declaration of Human Rights (UDHR)** | Art. 23: “Everyone has the right to work….” | Systematic denial of work based on prediction violates this right. |
# | **International Covenant on Economic, Social and Cultural Rights (ICESCR)** | Art. 2(2): “The steps…shall be taken without discrimination.” | Predictive exclusion based on socioeconomic/genetic factors would be discriminatory. |
# | **EU General Data Protection Regulation (GDPR)** | Art. 22: “Automated decision‑making…significant effect…must be subject to human review.” | The algorithm would need meaningful human oversight, which is hard to reconcile with blanket bans. |
# | **US Constitution (14th Amendment)** | Due Process Clause | Pre‑emptive denial without individualized due process likely violates procedural due process. |
#
# These legal norms reinforce the moral conclusion that such a policy would be impermissible in most jurisdictions.
#
# ---
#
# ## 6. The “No Alternative” Assumption – A Critical Examination
#
# Even if we *temporarily* accept that no other method matches the algorithm’s predictive power, we must ask:
#
# 1. **Is the assumption empirically sound?**
#    - Predictive models often improve with additional data and with more transparent, community‑based interventions (e.g., early education, mental‑health services). Declaring a “no alternative” prematurely shuts down research into less invasive, more equitable solutions.
#
# 2. **Do we have a moral right to accept a “best‑available” method that is itself deeply unjust?**
#    - The *means* must meet a minimal ethical threshold. A method that violates fundamental rights cannot be justified merely because it is the most effective *available* tool.
#
# 3. **Is the trade‑off proportionate?**
#    - Proportionality demands that the severity of the intrusion (denial of life‑shaping opportunities) be proportional to the seriousness of the threat. In most realistic calculations, the intrusion is *far* more severe than the prevented harm, especially given the high stakes for false positives.
#
# ---
#
# ## 7. Practical Counter‑Arguments & Rebuttals
#
# | **Common pro‑algorithm argument** | **Rebuttal** |
# |-----------------------------------|--------------|
# | *“The algorithm saves lives; we must act.”* | Saving lives is a laudable aim, but a policy that sacrifices the rights and futures of many innocent people creates a different kind of societal harm that can be equally lethal (social decay, increased violence, loss of trust). |
# | *“If we could only target the high‑risk group, crime would plummet.”* | The high‑risk group is identified *statistically*, not individually. Many of those labeled high‑risk would never have committed a crime; the policy would create a self‑fulfilling high‑risk class. |
# | *“We can’t afford alternative programs.”* | Budget constraints are a policy issue, not a moral justification for rights violations. Moreover, investing in universal prevention (education, health, community development) often yields higher cost‑effectiveness than punitive exclusion. |
# | *“The algorithm is neutral; bias is a myth.”* | Neutrality is an illusion when inputs reflect historic inequities. Genetic, socioeconomic, and environmental variables are socially constructed proxies for race, class, and geography. |
# | *“We can include a human review step to mitigate errors.”* | Human reviewers inherit the same biased data and are often subject to “automation bias” (over‑reliance on the algorithm). Moreover, the *structural* impact—loss of opportunity—remains even after a review. |
#
# ---
#
# ## 8. A More Ethical Path Forward
#
# 1. **Use the algorithm *only* for *supportive* interventions**, not for punitive exclusion.
#    - Example: Flag high‑risk individuals for *additional* counseling, mentorship, or targeted social services that aim to reduce risk while preserving opportunity.
#
# 2. **Invest in upstream prevention**: universal early‑childhood education, mental‑health care, job‑training programs, and community policing models have demonstrated efficacy in reducing crime without violating rights.
#
# 3. **Ensure transparency, accountability, and continuous auditing** of any predictive system. Include independent ethicists, community representatives, and legal scholars in oversight.
#
# 4. **Implement robust due‑process safeguards**: any decision that materially affects a person’s life (e.g., hiring, admission) must be explainable, contestable, and based on individualized evidence—not a statistical score.
#
# 5. **Collect and analyze data on false‑positive harms** to monitor whether the system is causing more damage than benefit. If the harm outweighs the benefit, discontinue the practice.
#
# ---
#
# ## 9. Bottom‑Line Moral Verdict
#
# - **From a deontological and rights‑based standpoint:** Denying education or employment on the basis of a predictive algorithm is morally impermissible because it punishes people for crimes they have not committed, violates the principle of proportionality, and breaches the right to equal treatment and due process.
# - **From a consequentialist standpoint:** Even if the algorithm is highly accurate, the aggregate harms—false‑positive losses, social destabilization, reinforcement of structural inequality—are likely to outweigh the benefits of crimes prevented, especially when the baseline rate of serious crime is low.
# - **From a virtue‑ethics/communitarian standpoint:** Such a policy erodes the moral character of the community, replacing compassion and rehabilitation with suspicion and exclusion.
#
# **Therefore, the use of the algorithm to *deny* individuals access to education or employment is not morally justified, even under the “no alternative” assumption.** The ethically appropriate use of predictive tools is to *inform* supportive, restorative measures that enhance rather than restrict life opportunities.
#
# # Response from competitor 5
#
# The hypothetical scenario you've presented raises complex ethical considerations. I'll break down the arguments for and against using the algorithm to deny access to educational and employment opportunities.
#
# **Arguments For Using the Algorithm:**
#
# 1. **Public Safety:** The primary purpose of a predictive algorithm is to prevent crimes, thereby ensuring public safety. By denying certain individuals access to employment or education, you may be reducing the likelihood of them committing a crime.
# 2. **Resource Allocation:** The algorithm might be used to prioritize resources and focus on interventions that could make a significant difference in preventing crimes.
# 3. **Preventive Measures over Punitive Ones:** Instead of solely relying on punishment, the algorithm's approach emphasizes preventive measures, which could lead to a more humane and effective justice system.
#
# **Arguments Against Using the Algorithm:**
#
# 1. **Discrimination and Stigma:** Denying access to essential resources based on statistical probability can lead to discrimination against certain groups, exacerbating existing social inequalities.
# 2. **Lack of Due Process:** The algorithm's results are not necessarily based on evidence of guilt or wrongdoing but rather predictions of potential future behavior. This raises concerns about whether the individuals in question have been unfairly judged and stripped of opportunities before their rights have been fully determined through traditional legal processes.
# 3. **Potential for Error and Bias:** Even with high accuracy rates, there's always a possibility that the algorithm is incorrect, underrepresenting or overrepresenting specific groups due to its own biases or lack of data representation. This could lead to unjust outcomes and perpetuate systemic injustices.
#
# **Mitigating Measures:**
#
# 1. **Use as Part of a Holistic Approach:** Consider integrating AI-driven predictive tools into larger programs designed to prevent crime, including social support services, mentorship, job training, education initiatives, and evidence-based therapeutic interventions.
# 2. **Address Systemic Inequalities:** Make efforts to address the underlying socioeconomic factors that contribute to higher crime rates by investing in programs aimed at poverty reduction, access to healthcare, mental health support, and other systemic inequalities.
#
# **In Conclusion:**
#
# The use of AI-driven predictive algorithms like this one raises complex questions regarding the balance between public safety, individual rights, and resource allocation. While there might be potential benefits from such an approach, it's crucial to implement these programs with care, considering factors like data quality, bias minimization, transparency about decision-making processes, and thorough evaluation of their effectiveness.
#
# Alternative solutions could incorporate AI-driven predictions alongside traditional justice systems, focusing on rehabilitation and support services rather than simply denying opportunities to those deemed unlikely to commit crimes. These considerations would require continuous debate, research, and adjustment as new evidence emerges.
#
# **Future Directions:**
#
# 1.   Engaging the Community:**  A thorough evaluation of the algorithm's effectiveness in different communities.
# 2.   Researching Alternative Approaches with Superior Humanitarian Impact
# 3.   Fostering Ongoing Dialogue on Fairness and Transparency
# 4.   Prioritizing Education, Employment and Social Support

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 5 competitors.
# Each model has been given this question:
#
# A hypothetical society has developed a predictive algorithm capable of determining with 95% accuracy the likelihood that an individual will commit a serious crime within the next five years. The algorithm considers numerous variables, including genetic predispositions, socioeconomic factors, environmental influences, and past behavior.
#
# Does it morally justify the use of this algorithm to deny certain individuals access to educational and employment opportunities, potentially altering their life trajectory, in order to prevent a statistically significant number of crimes from being committed, assuming no alternative method is available to achieve the same level of predictive accuracy?
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# The use of this algorithm raises complex moral and ethical concerns. While it could potentially prevent a significant number of crimes, denying individuals access to educational and employment opportunities could have far-reaching consequences that compromise their autonomy, dignity, and humanity.
#
# Here are some arguments against using the algorithm in this way:
#
# 1. **Predictive accuracy does not equal destiny**: A 95% accuracy rate may seem impressive, but it also means 5% of individuals predicted to commit crimes may not actually do so. This margin of error raises concerns about false positives and the potential for wrongful targeting of individuals.
# 2. **Stereotyping and stigmatization**: By identifying individuals as "high-risk" based on a set of predictive factors, the algorithm may perpetuate discriminatory stereotypes and stigmatize certain groups, such as those from lower socioeconomic backgrounds or with mental health conditions.
# 3. **Targeting the vulnerable**: The algorithm may disproportionately target individuals who are already vulnerable, such as those who are young, marginalized, or struggling financially. This could exacerbate existing social inequalities and create a self-fulfilling prophecy.
# 4. **Lack of control and agency**: By denying individuals access to educational and employment opportunities, the algorithm would be effectively controlling their life trajectory without their consent or input. This raises concerns about autonomy and the right to make choices about one's own life.
# 5. **Alternative methods**: The algorithm's high predictive accuracy may be due in part to its reliance on socioeconomic factors, which can be influenced by systemic inequalities. Instead of relying on the algorithm, policymakers might focus on addressing the root causes of crime, such as poverty, lack of education and job opportunities, and mental health issues.
# 6. **Potential for misuse**: The algorithm could be used to justify discriminatory practices, such as targeting specific racial or ethnic groups, or to justify the expansion of the prison system.
#
# To justify the use of the algorithm, one might argue that:
#
# 1. **Preventing harm**: By preventing a statistically significant number of crimes, the algorithm could save lives and reduce the burden on law enforcement and the justice system.
# 2. **Evidence-based decision-making**: The algorithm's high predictive accuracy provides a data-driven approach to decision-making, which could lead to more effective crime prevention strategies.
#
# However, even in the presence of strong evidence, the moral justification for using the algorithm to deny individuals access to educational and employment opportunities is dubious. This approach raises more questions than answers:
#
# 1. **What are the long-term consequences of "preventing" crime by targeting individuals?**
# 2. **How will you ensure that the algorithm is transparent, fair, and unbiased?**
# 3. **What safeguards will you put in place to prevent over-reliance on the algorithm and potential misuse?**
#
# Ultimately, the use of this algorithm should be approached with caution and rigorous ethical consideration. While it may have potential benefits, its risks and limitations must be thoroughly explored and addressed before it is used to inform high-stakes decisions about individual lives.
#
# # Response from competitor 2
#
# The use of a predictive algorithm to deny individuals access to educational and employment opportunities raises significant moral concerns. While the goal of preventing crimes is laudable, it is not morally justifiable to use this algorithm in the proposed manner for several reasons:
#
# 1. **Presumption of Innocence**: The algorithm's prediction is based on probability, not certainty. This means that 5% of individuals identified as high-risk will not commit a crime, and they will be unfairly denied opportunities. It is essential to presume innocence until proven guilty, rather than punishing individuals for potential future actions.
# 2. **Discrimination and Bias**: The algorithm may perpetuate existing social biases and discrimination, particularly if the variables used to train the model reflect historical inequalities. For example, socioeconomic factors may disproportionately affect marginalized communities, leading to unfair targeting of these groups.
# 3. **Lack of Personal Autonomy**: Denying individuals access to opportunities based on a statistical prediction undermines their autonomy and freedom to make choices about their lives. People have the right to pursue education and employment, even if they may be at a higher risk of committing a crime.
# 4. **Unintended Consequences**: Implementing such a system could lead to unintended consequences, such as:
# 	* Labeling individuals as "high-risk" can become a self-fulfilling prophecy, as they may become more likely to engage in criminal behavior due to the stigma and limited opportunities.
# 	* The lack of access to education and employment may exacerbate socioeconomic issues, potentially increasing the likelihood of crime.
# 	* The system may create a culture of suspicion, where individuals are viewed as potential threats rather than as members of society deserving of support and rehabilitation.
# 5. **Alternative Approaches**: Instead of relying solely on predictive algorithms, it is essential to explore alternative methods that focus on rehabilitation, social support, and addressing the root causes of crime. This could include:
# 	* Providing access to education, job training, and mental health services to individuals at risk.
# 	* Implementing community-based programs that promote social cohesion and address socioeconomic disparities.
# 	* Fostering a culture of rehabilitation and restorative justice, rather than punishment and exclusion.
# 6. **Transparency and Accountability**: The development and implementation of such an algorithm should be transparent, with clear guidelines and oversight mechanisms in place to ensure accountability and prevent abuse.
# 7. **Human Rights**: The use of predictive algorithms to deny opportunities raises concerns about human rights, including the right to education, employment, and non-discrimination. It is essential to ensure that any system implemented respects and protects these fundamental rights.
#
# In conclusion, while the predictive algorithm may be effective in identifying individuals at risk of committing crimes, it is not morally justifiable to use it to deny access to educational and employment opportunities. Instead, a more nuanced approach should be adopted, focusing on rehabilitation, social support, and addressing the root causes of crime, while ensuring that individual rights and autonomy are respected.
#
# # Response from competitor 3
#
# This hypothetical scenario presents a profound ethical dilemma, pitting the collective good of crime prevention against individual rights and liberties. While the algorithm's 95% accuracy rate is very high, most ethical frameworks would find its use to deny fundamental opportunities morally problematic.
#
# Let's break down the ethical considerations:
#
# **Arguments for Justification (primarily Utilitarian/Consequentialist):**
#
# 1.  **Prevention of Harm:** The primary argument is that preventing a "statistically significant number of serious crimes" would save lives, prevent suffering, and reduce societal costs associated with crime. From a purely utilitarian perspective, if the net benefit (reduced crime) outweighs the harm (denial of opportunities), it could be argued as justified.
# 2.  **High Accuracy:** The 95% accuracy rate is a powerful factor. It suggests that a large majority of those identified would indeed commit serious crimes.
# 3.  **No Alternative:** The premise states no alternative method exists to achieve the same level of predictive accuracy, suggesting this is the most effective means to the desired end of crime prevention.
#
# **Arguments Against Justification (primarily Deontological/Rights-Based and Virtue Ethics):**
#
# 1.  **Violation of Individual Rights and Autonomy:**
#     *   **Presumption of Innocence:** A cornerstone of modern justice systems is that individuals are presumed innocent until proven guilty. This algorithm effectively presumes a high likelihood of guilt for a future crime, punishing individuals before any actual wrongdoing.
#     *   **Right to Opportunity:** Denying access to education and employment fundamentally curtails an individual's right to pursue a fulfilling life, improve their socioeconomic status, and contribute to society.
#     *   **Free Will and Self-Determination:** Individuals are denied the chance to make their own choices, to change their path, or to prove the algorithm wrong. It treats individuals as deterministic outcomes of variables rather than agents with free will.
#
# 2.  **False Positives (5% Inaccuracy):**
#     *   While 5% may seem small, it means that 1 in 20 individuals identified by the algorithm would *not* have committed a serious crime. These individuals would suffer profound, lifelong consequences – denied education, employment, and social mobility – for actions they would never have taken. This is a severe injustice for a significant number of people.
#     *   The harm inflicted on these innocent individuals is immense and cannot be easily dismissed for the "greater good."
#
# 3.  **Self-Fulfilling Prophecy:**
#     *   Denying education and employment opportunities could, paradoxically, increase the likelihood of crime. If legitimate pathways to success and survival are blocked, individuals might be driven to illegal means out of desperation, resentment, or a lack of alternatives. This could make the algorithm's predictions "come true" not because of inherent predisposition, but because of the societal reaction to the prediction.
#
# 4.  **Moral Responsibility and Blame:**
#     *   If society denies individuals the means to live a legitimate life based on a prediction, what is society's responsibility for any subsequent criminal behavior? Does it absolve the individual of moral responsibility, or does it shift some of the blame to the system that limited their choices?
#
# 5.  **Discrimination and Systemic Bias:**
#     *   Even if the algorithm is designed to be "objective," if it incorporates socioeconomic factors or genetic predispositions, it risks perpetuating existing societal inequalities or creating new forms of discrimination. It could disproportionately impact certain communities or groups already facing systemic disadvantages, trapping them in a cycle of limited opportunity.
#
# 6.  **Slippery Slope:**
#     *   If this is deemed morally justifiable for "serious crimes," where does the line get drawn? Could it be extended to less serious offenses? Could it be used to deny other rights or opportunities, leading to a dystopian "pre-crime" society where individuals are constantly monitored and judged based on potential rather than actual actions?
#
# **Conclusion:**
#
# From a moral standpoint, the use of this algorithm to deny educational and employment opportunities is **not morally justified**.
#
# While the goal of preventing serious crime is laudable, the method employed fundamentally violates principles of individual liberty, the presumption of innocence, due process, and the right to opportunity. The harm inflicted on the 5% of false positives is an unacceptable injustice, and the potential for creating a self-fulfilling prophecy, exacerbating existing inequalities, and setting a dangerous precedent outweighs the utilitarian benefits of crime reduction.
#
# A just society should focus on rehabilitative, supportive, and interventionist strategies to address the root causes of crime, rather than preemptively punishing individuals for actions they might commit. The ethical cost of such a system is too high.
#
# # Response from competitor 4
#
# **Short answer:**
# Most mainstream moral frameworks would *not* consider it ethically permissible to deny people education or employment on the basis of a statistical prediction, even if that prediction could avert a large number of serious crimes and no equally accurate alternative exists. The harms of false‑positive judgments, the violation of fundamental rights, the risk of systemic bias, and the corrosive social consequences of “pre‑emptive” discrimination generally outweigh the utilitarian gain of preventing some future offenses.
#
# Below is a detailed analysis that explains why, drawing on several major ethical traditions, legal principles, and practical considerations.
#
# ---
#
# ## 1. The Core Moral Conflict
#
# | **Goal** | **Means** | **Key Moral Tension** |
# |----------|-----------|-----------------------|
# | Prevent serious crimes (utilitarian benefit) | Deny education/employment to those predicted to be high‑risk (pre‑emptive punishment) | Is it just to punish—or at least disadvantage—a person for something they have not yet done? |
#
# The dilemma pits **consequentialist reasoning** (maximizing overall safety) against **deontological and rights‑based reasoning** (respecting each individual’s autonomy, dignity, and equal treatment).
#
# ---
#
# ## 2. Consequentialist (Utilitarian / Consequence‑Based) Perspective
#
# ### 2.1. Expected‑Utility Calculation
#
# - **Accuracy:** 95 % true‑positive rate, 5 % false‑positive rate.
# - **Population size:** Suppose 1 million people are screened.
#   - True positives ≈ 0.95 × N<sub>high‑risk</sub>
#   - False positives ≈ 0.05 × N<sub>low‑risk</sub>
# - **Cost of denial:** Loss of education/employment reduces lifetime earnings, mental health, and social participation for each denied person.
# - **Benefit of prevented crimes:** Each serious crime avoided spares victims, families, and the criminal‑justice system large tangible and intangible costs.
#
# A rough utilitarian model would compare:
#
# ```
# Total Benefit = (Number of crimes prevented) × (average societal cost per crime)
# Total Harm    = (Number of false positives) × (average loss per person denied opportunity)
# ```
#
# If the **harm to false‑positives** exceeds the **benefit of crimes prevented**, a utilitarian calculus would deem the policy unjustifiable. Empirical studies on predictive policing show that even high‑accuracy tools produce sizable false‑positive pools because the base rate of serious crime is low. For a rare event, a 95 % “accuracy” can still misclassify many people.
#
# ### 2.2. Long‑Term Systemic Effects
#
# - **Stigmatization & Social Exclusion:** Systematically barring a segment of the population from key life pathways creates a self‑fulfilling prophecy: marginalized individuals face higher stress, reduced social capital, and limited legitimate avenues for success, all of which *increase* the probability of future offending.
# - **Erosion of Trust:** When institutions are seen as arbitrarily denying opportunities, public trust in education, labor markets, and the state declines, reducing overall societal cooperation—a crucial component of collective safety.
# - **Feedback Loops:** The algorithm is trained on historical data that already reflect past discrimination. Deploying it reinforces those patterns, potentially *degrading* the very predictive accuracy over time.
#
# Consequentialist reasoning must therefore factor in these indirect harms, which can outweigh the immediate crime‑prevention benefit.
#
# ---
#
# ## 3. Deontological / Rights‑Based Perspective
#
# ### 3.1. The Principle of Individual Moral Agency
#
# - **Punishment for non‑act:** Classical deontological ethics (e.g., Kantian) holds that individuals must be treated as ends in themselves, not merely as means to societal safety. Denying someone a chance at education or work *because they might* commit a crime treats them as a means to an end (crime reduction), violating their intrinsic dignity.
# - **Presumption of Innocence:** The legal and moral norm “innocent until proven guilty” is a safeguard against precisely this sort of pre‑emptive sanction. Using a statistical forecast to impose real penalties collapses that safeguard.
#
# ### 3.2. Equality & Non‑Discrimination
#
# - Even if the algorithm is “technically neutral,” the variables it uses (genetics, socioeconomic status, environment) are closely tied to protected classes (race, class, disability). Denying opportunities based on those variables effectively **discriminates** on the basis of group membership, violating modern conceptions of equal treatment.
# - Many moral and legal theories (e.g., Rawls’s *justice as fairness*) require that social and economic inequalities be arranged so that they benefit the *least advantaged*. A policy that systematically harms the disadvantaged to protect the majority fails this test.
#
# ### 3.3. Autonomy & Fair Process
#
# - Moral agency requires **fair process** (procedural justice). If an algorithm decides a person’s future without transparent appeal, it denies them the procedural rights that are essential to a just society.
#
# ---
#
# ## 4. Virtue‑Ethical and Communitarian Concerns
#
# - **Character of Society:** A community that pre‑emptively excludes people based on risk scores cultivates suspicion, fear, and a punitive ethos, eroding virtues such as compassion, solidarity, and forgiveness.
# - **Rehabilitation vs. Exclusion:** Virtue ethics emphasizes nurturing the potential for moral growth. Denying education/employment removes the very conditions that enable individuals to develop better habits and values.
#
# ---
#
# ## 5. Legal and International Human‑Rights Context
#
# | Instrument | Relevant Provision | Implication for the Algorithm |
# |------------|-------------------|------------------------------|
# | **Universal Declaration of Human Rights (UDHR)** | Art. 23: “Everyone has the right to work….” | Systematic denial of work based on prediction violates this right. |
# | **International Covenant on Economic, Social and Cultural Rights (ICESCR)** | Art. 2(2): “The steps…shall be taken without discrimination.” | Predictive exclusion based on socioeconomic/genetic factors would be discriminatory. |
# | **EU General Data Protection Regulation (GDPR)** | Art. 22: “Automated decision‑making…significant effect…must be subject to human review.” | The algorithm would need meaningful human oversight, which is hard to reconcile with blanket bans. |
# | **US Constitution (14th Amendment)** | Due Process Clause | Pre‑emptive denial without individualized due process likely violates procedural due process. |
#
# These legal norms reinforce the moral conclusion that such a policy would be impermissible in most jurisdictions.
#
# ---
#
# ## 6. The “No Alternative” Assumption – A Critical Examination
#
# Even if we *temporarily* accept that no other method matches the algorithm’s predictive power, we must ask:
#
# 1. **Is the assumption empirically sound?**
#    - Predictive models often improve with additional data and with more transparent, community‑based interventions (e.g., early education, mental‑health services). Declaring a “no alternative” prematurely shuts down research into less invasive, more equitable solutions.
#
# 2. **Do we have a moral right to accept a “best‑available” method that is itself deeply unjust?**
#    - The *means* must meet a minimal ethical threshold. A method that violates fundamental rights cannot be justified merely because it is the most effective *available* tool.
#
# 3. **Is the trade‑off proportionate?**
#    - Proportionality demands that the severity of the intrusion (denial of life‑shaping opportunities) be proportional to the seriousness of the threat. In most realistic calculations, the intrusion is *far* more severe than the prevented harm, especially given the high stakes for false positives.
#
# ---
#
# ## 7. Practical Counter‑Arguments & Rebuttals
#
# | **Common pro‑algorithm argument** | **Rebuttal** |
# |-----------------------------------|--------------|
# | *“The algorithm saves lives; we must act.”* | Saving lives is a laudable aim, but a policy that sacrifices the rights and futures of many innocent people creates a different kind of societal harm that can be equally lethal (social decay, increased violence, loss of trust). |
# | *“If we could only target the high‑risk group, crime would plummet.”* | The high‑risk group is identified *statistically*, not individually. Many of those labeled high‑risk would never have committed a crime; the policy would create a self‑fulfilling high‑risk class. |
# | *“We can’t afford alternative programs.”* | Budget constraints are a policy issue, not a moral justification for rights violations. Moreover, investing in universal prevention (education, health, community development) often yields higher cost‑effectiveness than punitive exclusion. |
# | *“The algorithm is neutral; bias is a myth.”* | Neutrality is an illusion when inputs reflect historic inequities. Genetic, socioeconomic, and environmental variables are socially constructed proxies for race, class, and geography. |
# | *“We can include a human review step to mitigate errors.”* | Human reviewers inherit the same biased data and are often subject to “automation bias” (over‑reliance on the algorithm). Moreover, the *structural* impact—loss of opportunity—remains even after a review. |
#
# ---
#
# ## 8. A More Ethical Path Forward
#
# 1. **Use the algorithm *only* for *supportive* interventions**, not for punitive exclusion.
#    - Example: Flag high‑risk individuals for *additional* counseling, mentorship, or targeted social services that aim to reduce risk while preserving opportunity.
#
# 2. **Invest in upstream prevention**: universal early‑childhood education, mental‑health care, job‑training programs, and community policing models have demonstrated efficacy in reducing crime without violating rights.
#
# 3. **Ensure transparency, accountability, and continuous auditing** of any predictive system. Include independent ethicists, community representatives, and legal scholars in oversight.
#
# 4. **Implement robust due‑process safeguards**: any decision that materially affects a person’s life (e.g., hiring, admission) must be explainable, contestable, and based on individualized evidence—not a statistical score.
#
# 5. **Collect and analyze data on false‑positive harms** to monitor whether the system is causing more damage than benefit. If the harm outweighs the benefit, discontinue the practice.
#
# ---
#
# ## 9. Bottom‑Line Moral Verdict
#
# - **From a deontological and rights‑based standpoint:** Denying education or employment on the basis of a predictive algorithm is morally impermissible because it punishes people for crimes they have not committed, violates the principle of proportionality, and breaches the right to equal treatment and due process.
# - **From a consequentialist standpoint:** Even if the algorithm is highly accurate, the aggregate harms—false‑positive losses, social destabilization, reinforcement of structural inequality—are likely to outweigh the benefits of crimes prevented, especially when the baseline rate of serious crime is low.
# - **From a virtue‑ethics/communitarian standpoint:** Such a policy erodes the moral character of the community, replacing compassion and rehabilitation with suspicion and exclusion.
#
# **Therefore, the use of the algorithm to *deny* individuals access to education or employment is not morally justified, even under the “no alternative” assumption.** The ethically appropriate use of predictive tools is to *inform* supportive, restorative measures that enhance rather than restrict life opportunities.
#
# # Response from competitor 5
#
# The hypothetical scenario you've presented raises complex ethical considerations. I'll break down the arguments for and against using the algorithm to deny access to educational and employment opportunities.
#
# **Arguments For Using the Algorithm:**
#
# 1. **Public Safety:** The primary purpose of a predictive algorithm is to prevent crimes, thereby ensuring public safety. By denying certain individuals access to employment or education, you may be reducing the likelihood of them committing a crime.
# 2. **Resource Allocation:** The algorithm might be used to prioritize resources and focus on interventions that could make a significant difference in preventing crimes.
# 3. **Preventive Measures over Punitive Ones:** Instead of solely relying on punishment, the algorithm's approach emphasizes preventive measures, which could lead to a more humane and effective justice system.
#
# **Arguments Against Using the Algorithm:**
#
# 1. **Discrimination and Stigma:** Denying access to essential resources based on statistical probability can lead to discrimination against certain groups, exacerbating existing social inequalities.
# 2. **Lack of Due Process:** The algorithm's results are not necessarily based on evidence of guilt or wrongdoing but rather predictions of potential future behavior. This raises concerns about whether the individuals in question have been unfairly judged and stripped of opportunities before their rights have been fully determined through traditional legal processes.
# 3. **Potential for Error and Bias:** Even with high accuracy rates, there's always a possibility that the algorithm is incorrect, underrepresenting or overrepresenting specific groups due to its own biases or lack of data representation. This could lead to unjust outcomes and perpetuate systemic injustices.
#
# **Mitigating Measures:**
#
# 1. **Use as Part of a Holistic Approach:** Consider integrating AI-driven predictive tools into larger programs designed to prevent crime, including social support services, mentorship, job training, education initiatives, and evidence-based therapeutic interventions.
# 2. **Address Systemic Inequalities:** Make efforts to address the underlying socioeconomic factors that contribute to higher crime rates by investing in programs aimed at poverty reduction, access to healthcare, mental health support, and other systemic inequalities.
#
# **In Conclusion:**
#
# The use of AI-driven predictive algorithms like this one raises complex questions regarding the balance between public safety, individual rights, and resource allocation. While there might be potential benefits from such an approach, it's crucial to implement these programs with care, considering factors like data quality, bias minimization, transparency about decision-making processes, and thorough evaluation of their effectiveness.
#
# Alternative solutions could incorporate AI-driven predictions alongside traditional justice systems, focusing on rehabilitation and support services rather than simply denying opportunities to those deemed unlikely to commit crimes. These considerations would require continuous debate, research, and adjustment as new evidence emerges.
#
# **Future Directions:**
#
# 1.   Engaging the Community:**  A thorough evaluation of the algorithm's effectiveness in different communities.
# 2.   Researching Alternative Approaches with Superior Humanitarian Impact
# 3.   Fostering Ongoing Dialogue on Fairness and Transparency
# 4.   Prioritizing Education, Employment and Social Support
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[55], line 4
#       1 # Judgement time!
#       2
#       3 openai = OpenAI()
# ----> 4 response = openai.chat.completions.create(
#       5     model="gpt-5-mini",
#       6     messages=judge_messages,
#       7 )
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1251, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1204 def create(
#    1205     self,
#    (...)   1248     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1249 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1250     validate_response_format(response_format)
# -> 1251     return self._post(
#    1252         "/chat/completions",
#    1253         body=maybe_transform(
#    1254             {
#    1255                 "messages": messages,
#    1256                 "model": model,
#    1257                 "audio": audio,
#    1258                 "frequency_penalty": frequency_penalty,
#    1259                 "function_call": function_call,
#    1260                 "functions": functions,
#    1261                 "logit_bias": logit_bias,
#    1262                 "logprobs": logprobs,
#    1263                 "max_completion_tokens": max_completion_tokens,
#    1264                 "max_tokens": max_tokens,
#    1265                 "metadata": metadata,
#    1266                 "modalities": modalities,
#    1267                 "moderation": moderation,
#    1268                 "n": n,
#    1269                 "parallel_tool_calls": parallel_tool_calls,
#    1270                 "prediction": prediction,
#    1271                 "presence_penalty": presence_penalty,
#    1272                 "prompt_cache_key": prompt_cache_key,
#    1273                 "prompt_cache_retention": prompt_cache_retention,
#    1274                 "reasoning_effort": reasoning_effort,
#    1275                 "response_format": response_format,
#    1276                 "safety_identifier": safety_identifier,
#    1277                 "seed": seed,
#    1278                 "service_tier": service_tier,
#    1279                 "stop": stop,
#    1280                 "store": store,
#    1281                 "stream": stream,
#    1282                 "stream_options": stream_options,
#    1283                 "temperature": temperature,
#    1284                 "tool_choice": tool_choice,
#    1285                 "tools": tools,
#    1286                 "top_logprobs": top_logprobs,
#    1287                 "top_p": top_p,
#    1288                 "user": user,
#    1289                 "verbosity": verbosity,
#    1290                 "web_search_options": web_search_options,
#    1291             },
#    1292             completion_create_params.CompletionCreateParamsStreaming
#    1293             if stream
#    1294             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1295         ),
#    1296         options=make_request_options(
#    1297             extra_headers=extra_headers,
#    1298             extra_query=extra_query,
#    1299             extra_body=extra_body,
#    1300             timeout=timeout,
#    1301             security={"bearer_auth": True},
#    1302         ),
#    1303         cast_to=ChatCompletion,
#    1304         stream=stream or False,
#    1305         stream_cls=Stream[ChatCompletionChunk],
#    1306     )
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\My Data\Projects\Ai\AI Engineer Agentic Track The Complete Agent & MCP Course\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
from groq import Groq

groq_client = Groq(api_key=os.getenv("GROQ_API_KEY"))

response = groq_client.chat.completions.create(
    model="llama-3.3-70b-versatile",  # most capable free model = better judge
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["3", "1", "2", "5", "4"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gemini-2.5-flash
# Rank 2: llama-3.1-8b-instant
# Rank 3: llama-3.3-70b-versatile
# Rank 4: llama3.2
# Rank 5: openai/gpt-oss-120b

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
